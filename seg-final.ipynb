# %%
# !pip install -U segmentation-models-pytorch
# Out:
# Collecting segmentation-models-pytorch
#   Downloading segmentation_models_pytorch-0.4.0-py3-none-any.whl.metadata (32 kB)
# Collecting efficientnet-pytorch>=0.6.1 (from segmentation-models-pytorch)
#   Downloading efficientnet_pytorch-0.7.1.tar.gz (21 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: huggingface-hub>=0.24 in /usr/local/lib/python3.10/dist-packages (from segmentation-models-pytorch) (0.29.0)
# Requirement already satisfied: numpy>=1.19.3 in /usr/local/lib/python3.10/dist-packages (from segmentation-models-pytorch) (1.26.4)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.10/dist-packages (from segmentation-models-pytorch) (11.0.0)
# Collecting pretrainedmodels>=0.7.1 (from segmentation-models-pytorch)
#   Downloading pretrainedmodels-0.7.4.tar.gz (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 5.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from segmentation-models-pytorch) (1.17.0)
# Requirement already satisfied: timm>=0.9 in /usr/local/lib/python3.10/dist-packages (from segmentation-models-pytorch) (1.0.12)
# Requirement already satisfied: torch>=1.8 in /usr/local/lib/python3.10/dist-packages (from segmentation-models-pytorch) (2.5.1+cu121)
# Requirement already satisfied: torchvision>=0.9 in /usr/local/lib/python3.10/dist-packages (from segmentation-models-pytorch) (0.20.1+cu121)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from segmentation-models-pytorch) (4.67.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.24->segmentation-models-pytorch) (3.17.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.24->segmentation-models-pytorch) (2024.12.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.24->segmentation-models-pytorch) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.24->segmentation-models-pytorch) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.24->segmentation-models-pytorch) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.24->segmentation-models-pytorch) (4.12.2)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.10/dist-packages (from numpy>=1.19.3->segmentation-models-pytorch) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.10/dist-packages (from numpy>=1.19.3->segmentation-models-pytorch) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.10/dist-packages (from numpy>=1.19.3->segmentation-models-pytorch) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.10/dist-packages (from numpy>=1.19.3->segmentation-models-pytorch) (2025.0.1)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.10/dist-packages (from numpy>=1.19.3->segmentation-models-pytorch) (2022.0.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.10/dist-packages (from numpy>=1.19.3->segmentation-models-pytorch) (2.4.1)
# Collecting munch (from pretrainedmodels>=0.7.1->segmentation-models-pytorch)
#   Downloading munch-4.0.0-py2.py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.10/dist-packages (from timm>=0.9->segmentation-models-pytorch) (0.4.5)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.8->segmentation-models-pytorch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8->segmentation-models-pytorch) (3.1.4)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8->segmentation-models-pytorch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.8->segmentation-models-pytorch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.8->segmentation-models-pytorch) (3.0.2)
# Requirement already satisfied: intel-openmp>=2024 in /usr/local/lib/python3.10/dist-packages (from mkl->numpy>=1.19.3->segmentation-models-pytorch) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.10/dist-packages (from mkl->numpy>=1.19.3->segmentation-models-pytorch) (2022.0.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.10/dist-packages (from tbb==2022.*->mkl->numpy>=1.19.3->segmentation-models-pytorch) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.10/dist-packages (from mkl_umath->numpy>=1.19.3->segmentation-models-pytorch) (2024.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.24->segmentation-models-pytorch) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.24->segmentation-models-pytorch) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.24->segmentation-models-pytorch) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.24->segmentation-models-pytorch) (2025.1.31)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.10/dist-packages (from intel-openmp>=2024->mkl->numpy>=1.19.3->segmentation-models-pytorch) (2024.2.0)
# Downloading segmentation_models_pytorch-0.4.0-py3-none-any.whl (121 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.3/121.3 kB 8.9 MB/s eta 0:00:00
# Downloading munch-4.0.0-py2.py3-none-any.whl (9.9 kB)
# Building wheels for collected packages: efficientnet-pytorch, pretrainedmodels
#   Building wheel for efficientnet-pytorch (setup.py) ... done
#   Created wheel for efficientnet-pytorch: filename=efficientnet_pytorch-0.7.1-py3-none-any.whl size=16424 sha256=62000c286f6eed0a41cea6042886327184fd308cf37ce32b8d6617e335d09774
#   Stored in directory: /root/.cache/pip/wheels/03/3f/e9/911b1bc46869644912bda90a56bcf7b960f20b5187feea3baf
#   Building wheel for pretrainedmodels (setup.py) ... done
#   Created wheel for pretrainedmodels: filename=pretrainedmodels-0.7.4-py3-none-any.whl size=60944 sha256=15a68d50cf6adbee6ff079af89881fa44271e5d9739f0cc67180369b5eb143a0
#   Stored in directory: /root/.cache/pip/wheels/35/cb/a5/8f534c60142835bfc889f9a482e4a67e0b817032d9c6883b64
# Successfully built efficientnet-pytorch pretrainedmodels
# Installing collected packages: munch, efficientnet-pytorch, pretrainedmodels, segmentation-models-pytorch
# Successfully installed efficientnet-pytorch-0.7.1 munch-4.0.0 pretrainedmodels-0.7.4 segmentation-models-pytorch-0.4.0

# %%
# !pip install -U albumentations
# Out:
# Requirement already satisfied: albumentations in /usr/local/lib/python3.10/dist-packages (1.4.20)
# Collecting albumentations
#   Downloading albumentations-2.0.5-py3-none-any.whl.metadata (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.7/41.7 kB 1.7 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.24.4 in /usr/local/lib/python3.10/dist-packages (from albumentations) (1.26.4)
# Requirement already satisfied: scipy>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from albumentations) (1.13.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from albumentations) (6.0.2)
# Requirement already satisfied: pydantic>=2.9.2 in /usr/local/lib/python3.10/dist-packages (from albumentations) (2.11.0a2)
# Collecting albucore==0.0.23 (from albumentations)
#   Downloading albucore-0.0.23-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: opencv-python-headless>=4.9.0.80 in /usr/local/lib/python3.10/dist-packages (from albumentations) (4.10.0.84)
# Requirement already satisfied: stringzilla>=3.10.4 in /usr/local/lib/python3.10/dist-packages (from albucore==0.0.23->albumentations) (3.11.1)
# Collecting simsimd>=5.9.2 (from albucore==0.0.23->albumentations)
#   Downloading simsimd-6.2.1-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.0/66.0 kB 4.3 MB/s eta 0:00:00
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.10/dist-packages (from numpy>=1.24.4->albumentations) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.10/dist-packages (from numpy>=1.24.4->albumentations) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.10/dist-packages (from numpy>=1.24.4->albumentations) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.10/dist-packages (from numpy>=1.24.4->albumentations) (2025.0.1)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.10/dist-packages (from numpy>=1.24.4->albumentations) (2022.0.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.10/dist-packages (from numpy>=1.24.4->albumentations) (2.4.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2.9.2->albumentations) (0.7.0)
# Requirement already satisfied: pydantic-core==2.29.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2.9.2->albumentations) (2.29.0)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2.9.2->albumentations) (4.12.2)
# Requirement already satisfied: intel-openmp>=2024 in /usr/local/lib/python3.10/dist-packages (from mkl->numpy>=1.24.4->albumentations) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.10/dist-packages (from mkl->numpy>=1.24.4->albumentations) (2022.0.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.10/dist-packages (from tbb==2022.*->mkl->numpy>=1.24.4->albumentations) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.10/dist-packages (from mkl_umath->numpy>=1.24.4->albumentations) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.10/dist-packages (from intel-openmp>=2024->mkl->numpy>=1.24.4->albumentations) (2024.2.0)
# Downloading albumentations-2.0.5-py3-none-any.whl (290 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.6/290.6 kB 11.1 MB/s eta 0:00:00
# Downloading albucore-0.0.23-py3-none-any.whl (14 kB)
# Downloading simsimd-6.2.1-cp310-cp310-manylinux_2_28_x86_64.whl (632 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 632.7/632.7 kB 22.6 MB/s eta 0:00:00
# Installing collected packages: simsimd, albucore, albumentations
#   Attempting uninstall: albucore
#     Found existing installation: albucore 0.0.19
#     Uninstalling albucore-0.0.19:
#       Successfully uninstalled albucore-0.0.19
#   Attempting uninstall: albumentations
#     Found existing installation: albumentations 1.4.20
#     Uninstalling albumentations-1.4.20:
#       Successfully uninstalled albumentations-1.4.20
# Successfully installed albucore-0.0.23 albumentations-2.0.5 simsimd-6.2.1

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset
import segmentation_models_pytorch as smp
import os
import numpy as np
from glob import glob
import json
from torchvision import transforms
from PIL import Image
import torch
import argparse
import warnings
import json
import os

# %%
import numpy as np
import torch
from torch.utils.data import Dataset, DataLoader
import cv2 as cv
from sklearn.model_selection import train_test_split
from torchvision.transforms import ToTensor
import random
from glob import glob

class RetinaDataset(Dataset):
    def __init__(self, images, masks, transform=None):
        self.images = images
        self.masks = masks
        self.to_tensor = ToTensor()
        self.transform = transform

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):

        image = cv.imread(self.images[idx], cv.IMREAD_COLOR)
        image = cv.cvtColor(image, cv.COLOR_BGR2RGB)

        mean = image.mean(axis=(0, 1))
        std = image.std(axis=(0, 1))
        image = (image - mean[None, None, :]) / std[None, None, :]
        image = image.astype(np.float32)

        mask = cv.imread(self.masks[idx], cv.IMREAD_GRAYSCALE)
        mask[mask > 0] = 1
        mask = mask.astype(np.float32)

        if self.transform:
            augmented = self.transform(image=image, mask=mask)
            image, mask = augmented["image"], augmented["mask"]

        image_tensor = self.to_tensor(image)
        mask_tensor = self.to_tensor(mask)

        return image_tensor, mask_tensor


def load_data(base_directory="/kaggle/input/retina-blood-vessel/Data", batch_size=4, train_transform=None, test_transform=None):
    train_images = sorted(glob(os.path.join(base_directory, "train", "image", "*.png")))
    train_masks = sorted(glob(os.path.join(base_directory, "train", "mask", "*.png")))
    test_images = sorted(glob(os.path.join(base_directory, "test", "image", "*.png")))
    test_masks = sorted(glob(os.path.join(base_directory, "test", "mask", "*.png")))

    train_images, val_images, train_masks, val_masks = train_test_split(
        train_images, train_masks, test_size=0.25, random_state=5
    )

    train_dataset = RetinaDataset(train_images, train_masks, transform=train_transform)
    val_dataset = RetinaDataset(val_images, val_masks, transform=test_transform)
    test_dataset = RetinaDataset(test_images, test_masks, transform=test_transform)

    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
    test_loader = DataLoader(test_dataset, batch_size=1, shuffle=False)

    return train_loader, val_loader, test_loader

# %%
def set_seed():
    torch.manual_seed(5)
    torch.cuda.manual_seed(5)
    torch.cuda.manual_seed_all(5)
    np.random.seed(5)
    random.seed(5)

# %%
import torch
import torch.nn as nn
import segmentation_models_pytorch as smp
from torch.utils.data import DataLoader
from sklearn.model_selection import train_test_split
import os
import numpy as np
from glob import glob
import albumentations as A


def conv_block(in_channels, out_channels):
    return nn.Sequential(
        nn.Conv2d(in_channels, out_channels, kernel_size=3, padding=1),
        nn.ReLU(inplace=True),
        nn.Conv2d(out_channels, out_channels, kernel_size=3, padding=1),
        nn.ReLU(inplace=True),
    )

class UNet(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(UNet, self).__init__()
        self.criterion = nn.BCEWithLogitsLoss()

        self.enc1 = conv_block(in_channels, 64)
        self.enc2 = conv_block(64, 128)
        self.enc3 = conv_block(128, 256)
        self.enc4 = conv_block(256, 512)
        self.enc5 = conv_block(512, 1024)

        self.pool = nn.MaxPool2d(kernel_size=2, stride=2)

        self.upconv4 = nn.ConvTranspose2d(1024, 512, kernel_size=2, stride=2)
        self.upconv3 = nn.ConvTranspose2d(512, 256, kernel_size=2, stride=2)
        self.upconv2 = nn.ConvTranspose2d(256, 128, kernel_size=2, stride=2)
        self.upconv1 = nn.ConvTranspose2d(128, 64, kernel_size=2, stride=2)

        self.dec1 = conv_block(1024, 512)
        self.dec2 = conv_block(512, 256)
        self.dec3 = conv_block(256, 128)
        self.dec4 = conv_block(128, 64)

        self.out = nn.Conv2d(64, out_channels, kernel_size=1)

        self.train_loss_sum = 0.0
        self.train_iou_sum = 0.0
        self.train_batches = 0
        self.val_loss_sum = 0.0
        self.val_iou_sum = 0.0
        self.val_batches = 0
        self.train_dice_sum = 0.0
        self.train_acc_sum = 0.0
        self.val_dice_sum = 0.0
        self.val_acc_sum = 0.0

    def forward(self, x):
        x1 = self.enc1(x)
        x2 = self.enc2(self.pool(x1))
        x3 = self.enc3(self.pool(x2))
        x4 = self.enc4(self.pool(x3))
        x5 = self.enc5(self.pool(x4))

        x = self.upconv4(x5)
        x = torch.cat([x, x4], dim=1)
        x = self.dec1(x)

        x = self.upconv3(x)
        x = torch.cat([x, x3], dim=1)
        x = self.dec2(x)

        x = self.upconv2(x)
        x = torch.cat([x, x2], dim=1)
        x = self.dec3(x)

        x = self.upconv1(x)
        x = torch.cat([x, x1], dim=1)
        x = self.dec4(x)

        x = self.out(x)
        return x
    def common_step(self, batch, batch_idx, device="cuda"):
        image, mask = batch
        image = image.to(device)
        mask = mask.to(device)
        pred = self.forward(image)
        loss = self.criterion(pred, mask)
        pred = torch.sigmoid(pred)
        mask = mask.round().long()
        tp, fp, fn, tn = smp.metrics.get_stats(pred, mask, mode="binary", threshold=0.5)  # type: ignore
        iou_score = smp.metrics.iou_score(tp, fp, fn, tn, reduction="micro").item()
        dice = (2 * tp.sum() / (2 * tp.sum() + fp.sum() + fn.sum())).item()
        acc = smp.metrics.accuracy(tp, fp, fn, tn, reduction="macro").item()
        return loss, iou_score, dice, acc

    def training_step(self, batch, batch_idx, device="cuda"):
        loss, iou_score, dice, acc = self.common_step(batch, batch_idx, device="cuda")
        self.train_loss_sum += loss
        self.train_iou_sum += iou_score
        self.train_dice_sum += dice
        self.train_acc_sum += acc
        self.train_batches += 1
        return loss,iou_score, dice, acc

    def on_train_epoch_end(self):
        avg_train_loss = self.train_loss_sum / self.train_batches
        avg_train_iou = self.train_iou_sum / self.train_batches
        avg_train_dice = self.train_dice_sum / self.train_batches
        avg_train_acc = self.train_acc_sum / self.train_batches
        self.train_loss_sum = 0.0
        self.train_iou_sum = 0.0
        self.train_dice_sum = 0.0
        self.train_acc_sum = 0.0
        self.train_batches = 0
        return avg_train_loss, avg_train_iou, avg_train_dice, avg_train_acc


    def validation_step(self, batch, batch_idx):
        loss, iou_score, dice, acc = self.common_step(batch, batch_idx, device="cuda")
        self.val_loss_sum += loss
        self.val_iou_sum += iou_score
        self.val_dice_sum += dice
        self.val_acc_sum += acc
        self.val_batches += 1
        return loss,iou_score, dice, acc

    def on_validation_epoch_end(self):
        avg_val_loss = self.val_loss_sum / self.val_batches
        avg_val_iou = self.val_iou_sum / self.val_batches
        avg_val_dice = self.val_dice_sum / self.val_batches
        avg_val_acc = self.val_acc_sum / self.val_batches
        self.val_loss_sum = 0.0
        self.val_iou_sum = 0.0
        self.val_dice_sum = 0.0
        self.val_acc_sum = 0.0
        self.val_batches = 0
        return avg_val_loss, avg_val_iou, avg_val_dice, avg_val_acc

def train_model(model, train_loader, val_loader, optimizer, num_epochs=800, patience=50, device="cuda"):
    model.to(device)
    criterion = nn.BCEWithLogitsLoss()
    best_val_iou = float("-inf")
    patience_counter = 0

    for epoch in range(num_epochs):
        model.train()
        train_loss, train_iou = 0.0, 0.0
        # enable gradient calculation
        torch.set_grad_enabled(True)

        for batch_idx, batch in enumerate(train_loader):
            train_loss, train_iou, train_dice, train_acc = model.training_step(batch, batch_idx)

            loss = train_loss  #loss scaled down by accumulation steps
            loss.backward()

            optimizer.step()
            optimizer.zero_grad()

            if batch_idx % 5 == 0:
                torch.set_grad_enabled(False)
                model.eval()
                # Validation loop
                for val_batch_idx, val_batch in enumerate(val_loader):
                    val_loss, val_iou, val_dice, val_acc = model.validation_step(val_batch, val_batch_idx)
                torch.set_grad_enabled(True)
                model.train()

        train_loss, train_iou, train_dice, train_acc = model.on_train_epoch_end()
        val_loss,val_iou, val_dice, val_acc = model.on_validation_epoch_end()
        print(f"Epoch {epoch+1}, Train Loss: {train_loss:.4f}, Train IoU: {train_iou:.4f}, Train Dice: {train_dice:.4f} , Train Accuracy: {train_acc:.4f}, Validation Loss: {val_loss:.4f}, Validation IoU: {val_iou:.4f}, Validation Dice: {val_dice:.4f} , Validation Accuracy: {val_acc:.4f}")
        # print(f"Epoch {epoch+1}, Train Loss: {train_loss:.4f}, Train IoU: {train_iou:.4f}")
        torch.save(model.state_dict(), "unet_seg.pth")

        if val_iou > best_val_iou:
                best_val_iou = val_iou
                patience_counter = 0
                torch.save(model.state_dict(), "best_iou_seg.pth")
        else:
                patience_counter += 1
                if patience_counter >= patience:
                    print("Early stopping triggered")
                    break

if __name__ == "__main__":
    set_seed()
    train_transform = A.Compose(
      [
          A.Resize(512, 512),
          A.HorizontalFlip(p=0.5),
          A.VerticalFlip(p=0.5),
          A.Rotate(limit=30, p=0.5),
          A.Sharpen(alpha=(0.5, 0.9), lightness=(0.5, 1.0), p=0.3),
          A.Emboss(alpha=(0.1, 0.3), strength=(0.5, 1.0), p=0.3),
      ]
    )
    test_transform = A.Compose(
      [
          A.Resize(512, 512),
      ]
    )

    train_loader, val_loader, test_loader = load_data(base_directory="/kaggle/input/retina-blood-vessel/Data",train_transform=train_transform)
    model = UNet(in_channels=3, out_channels=1)
    optimizer = torch.optim.Adam(model.parameters(), lr=0.0001)
    train_model(model, train_loader, val_loader, optimizer)
# Out:
# Epoch 1, Train Loss: 0.7086, Train IoU: 0.1243, Train Dice: 0.2204 , Train Accuracy: 0.2340, Validation Loss: 0.7063, Validation IoU: 0.1442, Validation Dice: 0.2511 , Validation Accuracy: 0.2427
# Epoch 2, Train Loss: 0.5431, Train IoU: 0.0001, Train Dice: 0.0003 , Train Accuracy: 0.8758, Validation Loss: 0.4761, Validation IoU: 0.0001, Validation Dice: 0.0002 , Validation Accuracy: 0.8749
# Epoch 3, Train Loss: 0.4110, Train IoU: 0.0000, Train Dice: 0.0000 , Train Accuracy: 0.8781, Validation Loss: 0.3620, Validation IoU: 0.0000, Validation Dice: 0.0000 , Validation Accuracy: 0.8750
# Epoch 4, Train Loss: 0.3751, Train IoU: 0.0000, Train Dice: 0.0000 , Train Accuracy: 0.8787, Validation Loss: 0.3492, Validation IoU: 0.0000, Validation Dice: 0.0000 , Validation Accuracy: 0.8750
# Epoch 5, Train Loss: 0.3588, Train IoU: 0.0000, Train Dice: 0.0000 , Train Accuracy: 0.8780, Validation Loss: 0.3449, Validation IoU: 0.0000, Validation Dice: 0.0000 , Validation Accuracy: 0.8750
# Epoch 6, Train Loss: 0.3512, Train IoU: 0.0000, Train Dice: 0.0000 , Train Accuracy: 0.8782, Validation Loss: 0.3449, Validation IoU: 0.0000, Validation Dice: 0.0000 , Validation Accuracy: 0.8750
# Epoch 7, Train Loss: 0.3409, Train IoU: 0.0000, Train Dice: 0.0000 , Train Accuracy: 0.8780, Validation Loss: 0.3427, Validation IoU: 0.0000, Validation Dice: 0.0000 , Validation Accuracy: 0.8750
# Epoch 8, Train Loss: 0.3349, Train IoU: 0.0000, Train Dice: 0.0000 , Train Accuracy: 0.8781, Validation Loss: 0.3352, Validation IoU: 0.0000, Validation Dice: 0.0000 , Validation Accuracy: 0.8750
# Epoch 9, Train Loss: 0.3260, Train IoU: 0.0000, Train Dice: 0.0000 , Train Accuracy: 0.8780, Validation Loss: 0.3280, Validation IoU: 0.0000, Validation Dice: 0.0000 , Validation Accuracy: 0.8750
# Epoch 10, Train Loss: 0.3169, Train IoU: 0.0000, Train Dice: 0.0000 , Train Accuracy: 0.8779, Validation Loss: 0.3173, Validation IoU: 0.0000, Validation Dice: 0.0000 , Validation Accuracy: 0.8750
# Epoch 11, Train Loss: 0.3093, Train IoU: 0.0000, Train Dice: 0.0000 , Train Accuracy: 0.8788, Validation Loss: 0.3113, Validation IoU: 0.0000, Validation Dice: 0.0000 , Validation Accuracy: 0.8750
# Epoch 12, Train Loss: 0.3075, Train IoU: 0.0000, Train Dice: 0.0000 , Train Accuracy: 0.8779, Validation Loss: 0.3064, Validation IoU: 0.0000, Validation Dice: 0.0000 , Validation Accuracy: 0.8750
# Epoch 13, Train Loss: 0.2981, Train IoU: 0.0000, Train Dice: 0.0000 , Train Accuracy: 0.8783, Validation Loss: 0.3013, Validation IoU: 0.0000, Validation Dice: 0.0000 , Validation Accuracy: 0.8750
# Epoch 14, Train Loss: 0.2910, Train IoU: 0.0000, Train Dice: 0.0000 , Train Accuracy: 0.8784, Validation Loss: 0.2949, Validation IoU: 0.0000, Validation Dice: 0.0000 , Validation Accuracy: 0.8750
# Epoch 15, Train Loss: 0.2919, Train IoU: 0.0002, Train Dice: 0.0003 , Train Accuracy: 0.8778, Validation Loss: 0.2914, Validation IoU: 0.0005, Validation Dice: 0.0010 , Validation Accuracy: 0.8750
# Epoch 16, Train Loss: 0.2856, Train IoU: 0.0019, Train Dice: 0.0038 , Train Accuracy: 0.8783, Validation Loss: 0.2853, Validation IoU: 0.0034, Validation Dice: 0.0068 , Validation Accuracy: 0.8754
# Epoch 17, Train Loss: 0.2758, Train IoU: 0.0104, Train Dice: 0.0205 , Train Accuracy: 0.8798, Validation Loss: 0.2782, Validation IoU: 0.0126, Validation Dice: 0.0247 , Validation Accuracy: 0.8765
# Epoch 18, Train Loss: 0.2606, Train IoU: 0.0816, Train Dice: 0.1462 , Train Accuracy: 0.8877, Validation Loss: 0.2582, Validation IoU: 0.0958, Validation Dice: 0.1715 , Validation Accuracy: 0.8867
# Epoch 19, Train Loss: 0.2469, Train IoU: 0.2308, Train Dice: 0.3688 , Train Accuracy: 0.9042, Validation Loss: 0.2439, Validation IoU: 0.2225, Validation Dice: 0.3618 , Validation Accuracy: 0.9018
# Epoch 20, Train Loss: 0.2314, Train IoU: 0.3597, Train Dice: 0.5253 , Train Accuracy: 0.9152, Validation Loss: 0.2344, Validation IoU: 0.3347, Validation Dice: 0.4982 , Validation Accuracy: 0.9131
# Epoch 21, Train Loss: 0.2231, Train IoU: 0.4126, Train Dice: 0.5820 , Train Accuracy: 0.9194, Validation Loss: 0.2313, Validation IoU: 0.3984, Validation Dice: 0.5671 , Validation Accuracy: 0.9163
# Epoch 22, Train Loss: 0.2217, Train IoU: 0.4112, Train Dice: 0.5807 , Train Accuracy: 0.9189, Validation Loss: 0.2099, Validation IoU: 0.4504, Validation Dice: 0.6202 , Validation Accuracy: 0.9225
# Epoch 23, Train Loss: 0.2178, Train IoU: 0.4025, Train Dice: 0.5673 , Train Accuracy: 0.9204, Validation Loss: 0.2168, Validation IoU: 0.4142, Validation Dice: 0.5788 , Validation Accuracy: 0.9205
# Epoch 24, Train Loss: 0.1985, Train IoU: 0.4629, Train Dice: 0.6318 , Train Accuracy: 0.9270, Validation Loss: 0.2037, Validation IoU: 0.4616, Validation Dice: 0.6301 , Validation Accuracy: 0.9251
# Epoch 25, Train Loss: 0.2029, Train IoU: 0.4550, Train Dice: 0.6213 , Train Accuracy: 0.9261, Validation Loss: 0.2080, Validation IoU: 0.4317, Validation Dice: 0.5993 , Validation Accuracy: 0.9234
# Epoch 26, Train Loss: 0.2073, Train IoU: 0.4594, Train Dice: 0.6283 , Train Accuracy: 0.9257, Validation Loss: 0.2179, Validation IoU: 0.4514, Validation Dice: 0.6185 , Validation Accuracy: 0.9236
# Epoch 27, Train Loss: 0.1980, Train IoU: 0.4636, Train Dice: 0.6315 , Train Accuracy: 0.9270, Validation Loss: 0.1969, Validation IoU: 0.4702, Validation Dice: 0.6381 , Validation Accuracy: 0.9280
# Epoch 28, Train Loss: 0.1902, Train IoU: 0.5010, Train Dice: 0.6667 , Train Accuracy: 0.9315, Validation Loss: 0.1973, Validation IoU: 0.4887, Validation Dice: 0.6544 , Validation Accuracy: 0.9282
# Epoch 29, Train Loss: 0.1888, Train IoU: 0.4965, Train Dice: 0.6629 , Train Accuracy: 0.9306, Validation Loss: 0.1864, Validation IoU: 0.5063, Validation Dice: 0.6714 , Validation Accuracy: 0.9307
# Epoch 30, Train Loss: 0.1810, Train IoU: 0.5134, Train Dice: 0.6776 , Train Accuracy: 0.9333, Validation Loss: 0.1819, Validation IoU: 0.4922, Validation Dice: 0.6590 , Validation Accuracy: 0.9310
# Epoch 31, Train Loss: 0.1815, Train IoU: 0.5125, Train Dice: 0.6770 , Train Accuracy: 0.9319, Validation Loss: 0.1837, Validation IoU: 0.5129, Validation Dice: 0.6762 , Validation Accuracy: 0.9316
# Epoch 32, Train Loss: 0.1801, Train IoU: 0.5185, Train Dice: 0.6822 , Train Accuracy: 0.9336, Validation Loss: 0.1760, Validation IoU: 0.5278, Validation Dice: 0.6903 , Validation Accuracy: 0.9336
# Epoch 33, Train Loss: 0.1756, Train IoU: 0.5288, Train Dice: 0.6909 , Train Accuracy: 0.9348, Validation Loss: 0.1778, Validation IoU: 0.5270, Validation Dice: 0.6895 , Validation Accuracy: 0.9335
# Epoch 34, Train Loss: 0.1727, Train IoU: 0.5313, Train Dice: 0.6933 , Train Accuracy: 0.9355, Validation Loss: 0.1721, Validation IoU: 0.5308, Validation Dice: 0.6930 , Validation Accuracy: 0.9348
# Epoch 35, Train Loss: 0.1721, Train IoU: 0.5392, Train Dice: 0.6996 , Train Accuracy: 0.9364, Validation Loss: 0.1726, Validation IoU: 0.5584, Validation Dice: 0.7163 , Validation Accuracy: 0.9358
# Epoch 36, Train Loss: 0.1673, Train IoU: 0.5458, Train Dice: 0.7057 , Train Accuracy: 0.9375, Validation Loss: 0.1696, Validation IoU: 0.5403, Validation Dice: 0.7010 , Validation Accuracy: 0.9358
# Epoch 37, Train Loss: 0.1736, Train IoU: 0.5393, Train Dice: 0.6997 , Train Accuracy: 0.9362, Validation Loss: 0.1704, Validation IoU: 0.5495, Validation Dice: 0.7087 , Validation Accuracy: 0.9363
# Epoch 38, Train Loss: 0.1707, Train IoU: 0.5407, Train Dice: 0.7012 , Train Accuracy: 0.9369, Validation Loss: 0.1686, Validation IoU: 0.5485, Validation Dice: 0.7079 , Validation Accuracy: 0.9368
# Epoch 39, Train Loss: 0.1655, Train IoU: 0.5488, Train Dice: 0.7084 , Train Accuracy: 0.9382, Validation Loss: 0.1684, Validation IoU: 0.5508, Validation Dice: 0.7098 , Validation Accuracy: 0.9370
# Epoch 40, Train Loss: 0.1740, Train IoU: 0.5383, Train Dice: 0.6989 , Train Accuracy: 0.9357, Validation Loss: 0.1660, Validation IoU: 0.5582, Validation Dice: 0.7160 , Validation Accuracy: 0.9376
# Epoch 41, Train Loss: 0.1680, Train IoU: 0.5495, Train Dice: 0.7088 , Train Accuracy: 0.9377, Validation Loss: 0.1655, Validation IoU: 0.5648, Validation Dice: 0.7216 , Validation Accuracy: 0.9376
# Epoch 42, Train Loss: 0.1680, Train IoU: 0.5445, Train Dice: 0.7046 , Train Accuracy: 0.9374, Validation Loss: 0.1661, Validation IoU: 0.5626, Validation Dice: 0.7195 , Validation Accuracy: 0.9374
# Epoch 43, Train Loss: 0.1677, Train IoU: 0.5513, Train Dice: 0.7104 , Train Accuracy: 0.9378, Validation Loss: 0.1678, Validation IoU: 0.5596, Validation Dice: 0.7170 , Validation Accuracy: 0.9374
# Epoch 44, Train Loss: 0.1685, Train IoU: 0.5490, Train Dice: 0.7079 , Train Accuracy: 0.9375, Validation Loss: 0.1643, Validation IoU: 0.5705, Validation Dice: 0.7262 , Validation Accuracy: 0.9389
# Epoch 45, Train Loss: 0.1636, Train IoU: 0.5618, Train Dice: 0.7190 , Train Accuracy: 0.9393, Validation Loss: 0.1639, Validation IoU: 0.5610, Validation Dice: 0.7183 , Validation Accuracy: 0.9382
# Epoch 46, Train Loss: 0.1628, Train IoU: 0.5567, Train Dice: 0.7146 , Train Accuracy: 0.9391, Validation Loss: 0.1632, Validation IoU: 0.5654, Validation Dice: 0.7219 , Validation Accuracy: 0.9385
# Epoch 47, Train Loss: 0.1648, Train IoU: 0.5549, Train Dice: 0.7132 , Train Accuracy: 0.9383, Validation Loss: 0.1621, Validation IoU: 0.5598, Validation Dice: 0.7172 , Validation Accuracy: 0.9389
# Epoch 48, Train Loss: 0.1618, Train IoU: 0.5654, Train Dice: 0.7220 , Train Accuracy: 0.9399, Validation Loss: 0.1612, Validation IoU: 0.5749, Validation Dice: 0.7298 , Validation Accuracy: 0.9396
# Epoch 49, Train Loss: 0.1622, Train IoU: 0.5635, Train Dice: 0.7202 , Train Accuracy: 0.9397, Validation Loss: 0.1608, Validation IoU: 0.5730, Validation Dice: 0.7282 , Validation Accuracy: 0.9399
# Epoch 50, Train Loss: 0.1629, Train IoU: 0.5652, Train Dice: 0.7208 , Train Accuracy: 0.9404, Validation Loss: 0.1596, Validation IoU: 0.5654, Validation Dice: 0.7220 , Validation Accuracy: 0.9397
# Epoch 51, Train Loss: 0.1644, Train IoU: 0.5538, Train Dice: 0.7122 , Train Accuracy: 0.9385, Validation Loss: 0.1634, Validation IoU: 0.5650, Validation Dice: 0.7217 , Validation Accuracy: 0.9390
# Epoch 52, Train Loss: 0.1628, Train IoU: 0.5573, Train Dice: 0.7154 , Train Accuracy: 0.9394, Validation Loss: 0.1579, Validation IoU: 0.5716, Validation Dice: 0.7271 , Validation Accuracy: 0.9404
# Epoch 53, Train Loss: 0.1636, Train IoU: 0.5626, Train Dice: 0.7195 , Train Accuracy: 0.9393, Validation Loss: 0.1617, Validation IoU: 0.5767, Validation Dice: 0.7310 , Validation Accuracy: 0.9393
# Epoch 54, Train Loss: 0.1658, Train IoU: 0.5536, Train Dice: 0.7123 , Train Accuracy: 0.9378, Validation Loss: 0.1617, Validation IoU: 0.5675, Validation Dice: 0.7235 , Validation Accuracy: 0.9397
# Epoch 55, Train Loss: 0.1654, Train IoU: 0.5545, Train Dice: 0.7122 , Train Accuracy: 0.9386, Validation Loss: 0.1611, Validation IoU: 0.5719, Validation Dice: 0.7272 , Validation Accuracy: 0.9398
# Epoch 56, Train Loss: 0.1621, Train IoU: 0.5687, Train Dice: 0.7246 , Train Accuracy: 0.9401, Validation Loss: 0.1645, Validation IoU: 0.5675, Validation Dice: 0.7237 , Validation Accuracy: 0.9395
# Epoch 57, Train Loss: 0.1609, Train IoU: 0.5643, Train Dice: 0.7212 , Train Accuracy: 0.9402, Validation Loss: 0.1566, Validation IoU: 0.5823, Validation Dice: 0.7358 , Validation Accuracy: 0.9410
# Epoch 58, Train Loss: 0.1607, Train IoU: 0.5698, Train Dice: 0.7253 , Train Accuracy: 0.9402, Validation Loss: 0.1609, Validation IoU: 0.5813, Validation Dice: 0.7348 , Validation Accuracy: 0.9395
# Epoch 59, Train Loss: 0.1593, Train IoU: 0.5716, Train Dice: 0.7269 , Train Accuracy: 0.9410, Validation Loss: 0.1557, Validation IoU: 0.5857, Validation Dice: 0.7385 , Validation Accuracy: 0.9414
# Epoch 60, Train Loss: 0.1592, Train IoU: 0.5713, Train Dice: 0.7263 , Train Accuracy: 0.9408, Validation Loss: 0.1547, Validation IoU: 0.5842, Validation Dice: 0.7372 , Validation Accuracy: 0.9415
# Epoch 61, Train Loss: 0.1560, Train IoU: 0.5798, Train Dice: 0.7335 , Train Accuracy: 0.9423, Validation Loss: 0.1582, Validation IoU: 0.5831, Validation Dice: 0.7363 , Validation Accuracy: 0.9409
# Epoch 62, Train Loss: 0.1514, Train IoU: 0.5908, Train Dice: 0.7424 , Train Accuracy: 0.9437, Validation Loss: 0.1514, Validation IoU: 0.5936, Validation Dice: 0.7448 , Validation Accuracy: 0.9428
# Epoch 63, Train Loss: 0.1561, Train IoU: 0.5770, Train Dice: 0.7312 , Train Accuracy: 0.9417, Validation Loss: 0.1522, Validation IoU: 0.5990, Validation Dice: 0.7490 , Validation Accuracy: 0.9427
# Epoch 64, Train Loss: 0.1591, Train IoU: 0.5719, Train Dice: 0.7274 , Train Accuracy: 0.9407, Validation Loss: 0.1528, Validation IoU: 0.5906, Validation Dice: 0.7424 , Validation Accuracy: 0.9425
# Epoch 65, Train Loss: 0.1575, Train IoU: 0.5813, Train Dice: 0.7343 , Train Accuracy: 0.9421, Validation Loss: 0.1553, Validation IoU: 0.5856, Validation Dice: 0.7384 , Validation Accuracy: 0.9413
# Epoch 66, Train Loss: 0.1534, Train IoU: 0.5851, Train Dice: 0.7380 , Train Accuracy: 0.9425, Validation Loss: 0.1513, Validation IoU: 0.5961, Validation Dice: 0.7467 , Validation Accuracy: 0.9430
# Epoch 67, Train Loss: 0.1549, Train IoU: 0.5815, Train Dice: 0.7349 , Train Accuracy: 0.9424, Validation Loss: 0.1532, Validation IoU: 0.5949, Validation Dice: 0.7457 , Validation Accuracy: 0.9421
# Epoch 68, Train Loss: 0.1517, Train IoU: 0.5909, Train Dice: 0.7426 , Train Accuracy: 0.9435, Validation Loss: 0.1507, Validation IoU: 0.5991, Validation Dice: 0.7491 , Validation Accuracy: 0.9431
# Epoch 69, Train Loss: 0.1531, Train IoU: 0.5863, Train Dice: 0.7387 , Train Accuracy: 0.9429, Validation Loss: 0.1490, Validation IoU: 0.6017, Validation Dice: 0.7511 , Validation Accuracy: 0.9437
# Epoch 70, Train Loss: 0.1574, Train IoU: 0.5752, Train Dice: 0.7293 , Train Accuracy: 0.9415, Validation Loss: 0.1507, Validation IoU: 0.5908, Validation Dice: 0.7425 , Validation Accuracy: 0.9432
# Epoch 71, Train Loss: 0.1539, Train IoU: 0.5830, Train Dice: 0.7362 , Train Accuracy: 0.9429, Validation Loss: 0.1536, Validation IoU: 0.5861, Validation Dice: 0.7387 , Validation Accuracy: 0.9423
# Epoch 72, Train Loss: 0.1555, Train IoU: 0.5811, Train Dice: 0.7345 , Train Accuracy: 0.9418, Validation Loss: 0.1528, Validation IoU: 0.5988, Validation Dice: 0.7488 , Validation Accuracy: 0.9426
# Epoch 73, Train Loss: 0.1519, Train IoU: 0.5891, Train Dice: 0.7410 , Train Accuracy: 0.9432, Validation Loss: 0.1522, Validation IoU: 0.5835, Validation Dice: 0.7365 , Validation Accuracy: 0.9427
# Epoch 74, Train Loss: 0.1510, Train IoU: 0.5939, Train Dice: 0.7443 , Train Accuracy: 0.9442, Validation Loss: 0.1517, Validation IoU: 0.5937, Validation Dice: 0.7446 , Validation Accuracy: 0.9433
# Epoch 75, Train Loss: 0.1540, Train IoU: 0.5786, Train Dice: 0.7323 , Train Accuracy: 0.9425, Validation Loss: 0.1490, Validation IoU: 0.6055, Validation Dice: 0.7541 , Validation Accuracy: 0.9440
# Epoch 76, Train Loss: 0.1539, Train IoU: 0.5841, Train Dice: 0.7371 , Train Accuracy: 0.9425, Validation Loss: 0.1489, Validation IoU: 0.5938, Validation Dice: 0.7449 , Validation Accuracy: 0.9437
# Epoch 77, Train Loss: 0.1503, Train IoU: 0.5910, Train Dice: 0.7426 , Train Accuracy: 0.9439, Validation Loss: 0.1475, Validation IoU: 0.6015, Validation Dice: 0.7510 , Validation Accuracy: 0.9443
# Epoch 78, Train Loss: 0.1485, Train IoU: 0.5960, Train Dice: 0.7464 , Train Accuracy: 0.9444, Validation Loss: 0.1471, Validation IoU: 0.6017, Validation Dice: 0.7511 , Validation Accuracy: 0.9444
# Epoch 79, Train Loss: 0.1495, Train IoU: 0.5939, Train Dice: 0.7450 , Train Accuracy: 0.9441, Validation Loss: 0.1465, Validation IoU: 0.6089, Validation Dice: 0.7568 , Validation Accuracy: 0.9447
# Epoch 80, Train Loss: 0.1471, Train IoU: 0.6003, Train Dice: 0.7501 , Train Accuracy: 0.9449, Validation Loss: 0.1472, Validation IoU: 0.6038, Validation Dice: 0.7527 , Validation Accuracy: 0.9442
# Epoch 81, Train Loss: 0.1495, Train IoU: 0.5938, Train Dice: 0.7449 , Train Accuracy: 0.9438, Validation Loss: 0.1474, Validation IoU: 0.5989, Validation Dice: 0.7489 , Validation Accuracy: 0.9444
# Epoch 82, Train Loss: 0.1470, Train IoU: 0.6034, Train Dice: 0.7523 , Train Accuracy: 0.9450, Validation Loss: 0.1453, Validation IoU: 0.6123, Validation Dice: 0.7593 , Validation Accuracy: 0.9451
# Epoch 83, Train Loss: 0.1453, Train IoU: 0.6025, Train Dice: 0.7516 , Train Accuracy: 0.9454, Validation Loss: 0.1447, Validation IoU: 0.6102, Validation Dice: 0.7578 , Validation Accuracy: 0.9453
# Epoch 84, Train Loss: 0.1463, Train IoU: 0.6063, Train Dice: 0.7546 , Train Accuracy: 0.9451, Validation Loss: 0.1431, Validation IoU: 0.6190, Validation Dice: 0.7645 , Validation Accuracy: 0.9456
# Epoch 85, Train Loss: 0.1550, Train IoU: 0.5848, Train Dice: 0.7376 , Train Accuracy: 0.9421, Validation Loss: 0.1560, Validation IoU: 0.5967, Validation Dice: 0.7472 , Validation Accuracy: 0.9416
# Epoch 86, Train Loss: 0.1542, Train IoU: 0.5775, Train Dice: 0.7318 , Train Accuracy: 0.9423, Validation Loss: 0.1513, Validation IoU: 0.5825, Validation Dice: 0.7354 , Validation Accuracy: 0.9429
# Epoch 87, Train Loss: 0.1492, Train IoU: 0.5929, Train Dice: 0.7437 , Train Accuracy: 0.9442, Validation Loss: 0.1463, Validation IoU: 0.6053, Validation Dice: 0.7539 , Validation Accuracy: 0.9447
# Epoch 88, Train Loss: 0.1482, Train IoU: 0.5981, Train Dice: 0.7480 , Train Accuracy: 0.9444, Validation Loss: 0.1468, Validation IoU: 0.6087, Validation Dice: 0.7565 , Validation Accuracy: 0.9445
# Epoch 89, Train Loss: 0.1498, Train IoU: 0.6000, Train Dice: 0.7493 , Train Accuracy: 0.9443, Validation Loss: 0.1464, Validation IoU: 0.6129, Validation Dice: 0.7598 , Validation Accuracy: 0.9446
# Epoch 90, Train Loss: 0.1499, Train IoU: 0.5952, Train Dice: 0.7457 , Train Accuracy: 0.9442, Validation Loss: 0.1444, Validation IoU: 0.6114, Validation Dice: 0.7586 , Validation Accuracy: 0.9456
# Epoch 91, Train Loss: 0.1474, Train IoU: 0.6009, Train Dice: 0.7501 , Train Accuracy: 0.9450, Validation Loss: 0.1449, Validation IoU: 0.6006, Validation Dice: 0.7502 , Validation Accuracy: 0.9449
# Epoch 92, Train Loss: 0.1471, Train IoU: 0.6026, Train Dice: 0.7517 , Train Accuracy: 0.9451, Validation Loss: 0.1422, Validation IoU: 0.6164, Validation Dice: 0.7625 , Validation Accuracy: 0.9462
# Epoch 93, Train Loss: 0.1512, Train IoU: 0.5911, Train Dice: 0.7425 , Train Accuracy: 0.9438, Validation Loss: 0.1463, Validation IoU: 0.6060, Validation Dice: 0.7543 , Validation Accuracy: 0.9453
# Epoch 94, Train Loss: 0.1435, Train IoU: 0.6121, Train Dice: 0.7592 , Train Accuracy: 0.9460, Validation Loss: 0.1456, Validation IoU: 0.6095, Validation Dice: 0.7571 , Validation Accuracy: 0.9450
# Epoch 95, Train Loss: 0.1452, Train IoU: 0.6066, Train Dice: 0.7547 , Train Accuracy: 0.9458, Validation Loss: 0.1413, Validation IoU: 0.6147, Validation Dice: 0.7612 , Validation Accuracy: 0.9463
# Epoch 96, Train Loss: 0.1461, Train IoU: 0.6030, Train Dice: 0.7521 , Train Accuracy: 0.9453, Validation Loss: 0.1439, Validation IoU: 0.6133, Validation Dice: 0.7601 , Validation Accuracy: 0.9457
# Epoch 97, Train Loss: 0.1435, Train IoU: 0.6102, Train Dice: 0.7575 , Train Accuracy: 0.9460, Validation Loss: 0.1409, Validation IoU: 0.6205, Validation Dice: 0.7656 , Validation Accuracy: 0.9465
# Epoch 98, Train Loss: 0.1438, Train IoU: 0.6079, Train Dice: 0.7558 , Train Accuracy: 0.9460, Validation Loss: 0.1405, Validation IoU: 0.6222, Validation Dice: 0.7670 , Validation Accuracy: 0.9467
# Epoch 99, Train Loss: 0.1472, Train IoU: 0.6039, Train Dice: 0.7523 , Train Accuracy: 0.9453, Validation Loss: 0.1514, Validation IoU: 0.5956, Validation Dice: 0.7460 , Validation Accuracy: 0.9434
# Epoch 100, Train Loss: 0.1454, Train IoU: 0.5991, Train Dice: 0.7490 , Train Accuracy: 0.9453, Validation Loss: 0.1444, Validation IoU: 0.6067, Validation Dice: 0.7551 , Validation Accuracy: 0.9452
# Epoch 101, Train Loss: 0.1407, Train IoU: 0.6171, Train Dice: 0.7629 , Train Accuracy: 0.9469, Validation Loss: 0.1405, Validation IoU: 0.6257, Validation Dice: 0.7696 , Validation Accuracy: 0.9466
# Epoch 102, Train Loss: 0.1430, Train IoU: 0.6090, Train Dice: 0.7564 , Train Accuracy: 0.9463, Validation Loss: 0.1444, Validation IoU: 0.6104, Validation Dice: 0.7577 , Validation Accuracy: 0.9457
# Epoch 103, Train Loss: 0.1475, Train IoU: 0.6029, Train Dice: 0.7520 , Train Accuracy: 0.9449, Validation Loss: 0.1468, Validation IoU: 0.6168, Validation Dice: 0.7626 , Validation Accuracy: 0.9449
# Epoch 104, Train Loss: 0.1435, Train IoU: 0.6064, Train Dice: 0.7548 , Train Accuracy: 0.9458, Validation Loss: 0.1408, Validation IoU: 0.6145, Validation Dice: 0.7611 , Validation Accuracy: 0.9463
# Epoch 105, Train Loss: 0.1422, Train IoU: 0.6111, Train Dice: 0.7582 , Train Accuracy: 0.9465, Validation Loss: 0.1404, Validation IoU: 0.6251, Validation Dice: 0.7692 , Validation Accuracy: 0.9465
# Epoch 106, Train Loss: 0.1416, Train IoU: 0.6106, Train Dice: 0.7579 , Train Accuracy: 0.9463, Validation Loss: 0.1387, Validation IoU: 0.6225, Validation Dice: 0.7672 , Validation Accuracy: 0.9471
# Epoch 107, Train Loss: 0.1402, Train IoU: 0.6184, Train Dice: 0.7637 , Train Accuracy: 0.9473, Validation Loss: 0.1383, Validation IoU: 0.6225, Validation Dice: 0.7672 , Validation Accuracy: 0.9474
# Epoch 108, Train Loss: 0.1391, Train IoU: 0.6212, Train Dice: 0.7660 , Train Accuracy: 0.9477, Validation Loss: 0.1375, Validation IoU: 0.6309, Validation Dice: 0.7736 , Validation Accuracy: 0.9475
# Epoch 109, Train Loss: 0.1396, Train IoU: 0.6154, Train Dice: 0.7616 , Train Accuracy: 0.9470, Validation Loss: 0.1369, Validation IoU: 0.6288, Validation Dice: 0.7720 , Validation Accuracy: 0.9479
# Epoch 110, Train Loss: 0.1381, Train IoU: 0.6213, Train Dice: 0.7662 , Train Accuracy: 0.9478, Validation Loss: 0.1368, Validation IoU: 0.6241, Validation Dice: 0.7684 , Validation Accuracy: 0.9480
# Epoch 111, Train Loss: 0.1405, Train IoU: 0.6165, Train Dice: 0.7624 , Train Accuracy: 0.9469, Validation Loss: 0.1385, Validation IoU: 0.6262, Validation Dice: 0.7700 , Validation Accuracy: 0.9470
# Epoch 112, Train Loss: 0.1384, Train IoU: 0.6205, Train Dice: 0.7655 , Train Accuracy: 0.9476, Validation Loss: 0.1368, Validation IoU: 0.6303, Validation Dice: 0.7731 , Validation Accuracy: 0.9479
# Epoch 113, Train Loss: 0.1377, Train IoU: 0.6231, Train Dice: 0.7676 , Train Accuracy: 0.9478, Validation Loss: 0.1381, Validation IoU: 0.6208, Validation Dice: 0.7659 , Validation Accuracy: 0.9472
# Epoch 114, Train Loss: 0.1440, Train IoU: 0.6130, Train Dice: 0.7597 , Train Accuracy: 0.9463, Validation Loss: 0.1375, Validation IoU: 0.6357, Validation Dice: 0.7771 , Validation Accuracy: 0.9479
# Epoch 115, Train Loss: 0.1422, Train IoU: 0.6096, Train Dice: 0.7564 , Train Accuracy: 0.9469, Validation Loss: 0.1466, Validation IoU: 0.6035, Validation Dice: 0.7523 , Validation Accuracy: 0.9447
# Epoch 116, Train Loss: 0.1410, Train IoU: 0.6159, Train Dice: 0.7620 , Train Accuracy: 0.9468, Validation Loss: 0.1409, Validation IoU: 0.6288, Validation Dice: 0.7718 , Validation Accuracy: 0.9468
# Epoch 117, Train Loss: 0.1410, Train IoU: 0.6156, Train Dice: 0.7615 , Train Accuracy: 0.9469, Validation Loss: 0.1369, Validation IoU: 0.6313, Validation Dice: 0.7739 , Validation Accuracy: 0.9479
# Epoch 118, Train Loss: 0.1400, Train IoU: 0.6182, Train Dice: 0.7637 , Train Accuracy: 0.9472, Validation Loss: 0.1402, Validation IoU: 0.6192, Validation Dice: 0.7645 , Validation Accuracy: 0.9468
# Epoch 119, Train Loss: 0.1397, Train IoU: 0.6183, Train Dice: 0.7635 , Train Accuracy: 0.9474, Validation Loss: 0.1358, Validation IoU: 0.6311, Validation Dice: 0.7737 , Validation Accuracy: 0.9483
# Epoch 120, Train Loss: 0.1385, Train IoU: 0.6216, Train Dice: 0.7664 , Train Accuracy: 0.9477, Validation Loss: 0.1381, Validation IoU: 0.6233, Validation Dice: 0.7678 , Validation Accuracy: 0.9473
# Epoch 121, Train Loss: 0.1375, Train IoU: 0.6234, Train Dice: 0.7673 , Train Accuracy: 0.9481, Validation Loss: 0.1340, Validation IoU: 0.6364, Validation Dice: 0.7777 , Validation Accuracy: 0.9487
# Epoch 122, Train Loss: 0.1373, Train IoU: 0.6230, Train Dice: 0.7674 , Train Accuracy: 0.9481, Validation Loss: 0.1357, Validation IoU: 0.6290, Validation Dice: 0.7720 , Validation Accuracy: 0.9482
# Epoch 123, Train Loss: 0.1353, Train IoU: 0.6257, Train Dice: 0.7693 , Train Accuracy: 0.9486, Validation Loss: 0.1343, Validation IoU: 0.6368, Validation Dice: 0.7780 , Validation Accuracy: 0.9487
# Epoch 124, Train Loss: 0.1372, Train IoU: 0.6253, Train Dice: 0.7692 , Train Accuracy: 0.9480, Validation Loss: 0.1366, Validation IoU: 0.6361, Validation Dice: 0.7774 , Validation Accuracy: 0.9481
# Epoch 125, Train Loss: 0.1385, Train IoU: 0.6174, Train Dice: 0.7630 , Train Accuracy: 0.9475, Validation Loss: 0.1368, Validation IoU: 0.6215, Validation Dice: 0.7664 , Validation Accuracy: 0.9475
# Epoch 126, Train Loss: 0.1347, Train IoU: 0.6285, Train Dice: 0.7716 , Train Accuracy: 0.9489, Validation Loss: 0.1332, Validation IoU: 0.6402, Validation Dice: 0.7805 , Validation Accuracy: 0.9489
# Epoch 127, Train Loss: 0.1337, Train IoU: 0.6331, Train Dice: 0.7750 , Train Accuracy: 0.9491, Validation Loss: 0.1335, Validation IoU: 0.6407, Validation Dice: 0.7809 , Validation Accuracy: 0.9488
# Epoch 128, Train Loss: 0.1341, Train IoU: 0.6292, Train Dice: 0.7722 , Train Accuracy: 0.9489, Validation Loss: 0.1345, Validation IoU: 0.6353, Validation Dice: 0.7768 , Validation Accuracy: 0.9482
# Epoch 129, Train Loss: 0.1365, Train IoU: 0.6219, Train Dice: 0.7665 , Train Accuracy: 0.9481, Validation Loss: 0.1358, Validation IoU: 0.6315, Validation Dice: 0.7740 , Validation Accuracy: 0.9480
# Epoch 130, Train Loss: 0.1380, Train IoU: 0.6221, Train Dice: 0.7668 , Train Accuracy: 0.9478, Validation Loss: 0.1340, Validation IoU: 0.6348, Validation Dice: 0.7765 , Validation Accuracy: 0.9487
# Epoch 131, Train Loss: 0.1376, Train IoU: 0.6191, Train Dice: 0.7646 , Train Accuracy: 0.9475, Validation Loss: 0.1328, Validation IoU: 0.6367, Validation Dice: 0.7779 , Validation Accuracy: 0.9493
# Epoch 132, Train Loss: 0.1350, Train IoU: 0.6291, Train Dice: 0.7721 , Train Accuracy: 0.9488, Validation Loss: 0.1340, Validation IoU: 0.6348, Validation Dice: 0.7765 , Validation Accuracy: 0.9485
# Epoch 133, Train Loss: 0.1360, Train IoU: 0.6269, Train Dice: 0.7703 , Train Accuracy: 0.9487, Validation Loss: 0.1345, Validation IoU: 0.6340, Validation Dice: 0.7759 , Validation Accuracy: 0.9483
# Epoch 134, Train Loss: 0.1362, Train IoU: 0.6267, Train Dice: 0.7702 , Train Accuracy: 0.9482, Validation Loss: 0.1320, Validation IoU: 0.6402, Validation Dice: 0.7806 , Validation Accuracy: 0.9495
# Epoch 135, Train Loss: 0.1351, Train IoU: 0.6271, Train Dice: 0.7705 , Train Accuracy: 0.9486, Validation Loss: 0.1335, Validation IoU: 0.6398, Validation Dice: 0.7802 , Validation Accuracy: 0.9487
# Epoch 136, Train Loss: 0.1339, Train IoU: 0.6321, Train Dice: 0.7743 , Train Accuracy: 0.9488, Validation Loss: 0.1324, Validation IoU: 0.6375, Validation Dice: 0.7785 , Validation Accuracy: 0.9492
# Epoch 137, Train Loss: 0.1333, Train IoU: 0.6287, Train Dice: 0.7717 , Train Accuracy: 0.9491, Validation Loss: 0.1321, Validation IoU: 0.6374, Validation Dice: 0.7784 , Validation Accuracy: 0.9492
# Epoch 138, Train Loss: 0.1333, Train IoU: 0.6343, Train Dice: 0.7758 , Train Accuracy: 0.9494, Validation Loss: 0.1345, Validation IoU: 0.6320, Validation Dice: 0.7743 , Validation Accuracy: 0.9485
# Epoch 139, Train Loss: 0.1387, Train IoU: 0.6218, Train Dice: 0.7664 , Train Accuracy: 0.9476, Validation Loss: 0.1329, Validation IoU: 0.6365, Validation Dice: 0.7777 , Validation Accuracy: 0.9489
# Epoch 140, Train Loss: 0.1379, Train IoU: 0.6229, Train Dice: 0.7670 , Train Accuracy: 0.9481, Validation Loss: 0.1328, Validation IoU: 0.6395, Validation Dice: 0.7800 , Validation Accuracy: 0.9493
# Epoch 141, Train Loss: 0.1321, Train IoU: 0.6349, Train Dice: 0.7763 , Train Accuracy: 0.9495, Validation Loss: 0.1325, Validation IoU: 0.6406, Validation Dice: 0.7808 , Validation Accuracy: 0.9494
# Epoch 142, Train Loss: 0.1322, Train IoU: 0.6337, Train Dice: 0.7756 , Train Accuracy: 0.9495, Validation Loss: 0.1307, Validation IoU: 0.6395, Validation Dice: 0.7800 , Validation Accuracy: 0.9497
# Epoch 143, Train Loss: 0.1304, Train IoU: 0.6411, Train Dice: 0.7811 , Train Accuracy: 0.9501, Validation Loss: 0.1310, Validation IoU: 0.6479, Validation Dice: 0.7862 , Validation Accuracy: 0.9497
# Epoch 144, Train Loss: 0.1323, Train IoU: 0.6337, Train Dice: 0.7756 , Train Accuracy: 0.9494, Validation Loss: 0.1308, Validation IoU: 0.6366, Validation Dice: 0.7778 , Validation Accuracy: 0.9497
# Epoch 145, Train Loss: 0.1290, Train IoU: 0.6413, Train Dice: 0.7813 , Train Accuracy: 0.9507, Validation Loss: 0.1286, Validation IoU: 0.6504, Validation Dice: 0.7881 , Validation Accuracy: 0.9505
# Epoch 146, Train Loss: 0.1307, Train IoU: 0.6398, Train Dice: 0.7801 , Train Accuracy: 0.9500, Validation Loss: 0.1282, Validation IoU: 0.6518, Validation Dice: 0.7891 , Validation Accuracy: 0.9506
# Epoch 147, Train Loss: 0.1316, Train IoU: 0.6360, Train Dice: 0.7772 , Train Accuracy: 0.9496, Validation Loss: 0.1302, Validation IoU: 0.6421, Validation Dice: 0.7818 , Validation Accuracy: 0.9498
# Epoch 148, Train Loss: 0.1311, Train IoU: 0.6381, Train Dice: 0.7788 , Train Accuracy: 0.9497, Validation Loss: 0.1287, Validation IoU: 0.6488, Validation Dice: 0.7868 , Validation Accuracy: 0.9504
# Epoch 149, Train Loss: 0.1302, Train IoU: 0.6428, Train Dice: 0.7821 , Train Accuracy: 0.9505, Validation Loss: 0.1306, Validation IoU: 0.6432, Validation Dice: 0.7828 , Validation Accuracy: 0.9496
# Epoch 150, Train Loss: 0.1282, Train IoU: 0.6452, Train Dice: 0.7840 , Train Accuracy: 0.9511, Validation Loss: 0.1274, Validation IoU: 0.6493, Validation Dice: 0.7873 , Validation Accuracy: 0.9509
# Epoch 151, Train Loss: 0.1306, Train IoU: 0.6378, Train Dice: 0.7784 , Train Accuracy: 0.9499, Validation Loss: 0.1305, Validation IoU: 0.6405, Validation Dice: 0.7806 , Validation Accuracy: 0.9497
# Epoch 152, Train Loss: 0.1288, Train IoU: 0.6457, Train Dice: 0.7844 , Train Accuracy: 0.9510, Validation Loss: 0.1280, Validation IoU: 0.6509, Validation Dice: 0.7885 , Validation Accuracy: 0.9508
# Epoch 153, Train Loss: 0.1301, Train IoU: 0.6412, Train Dice: 0.7811 , Train Accuracy: 0.9505, Validation Loss: 0.1282, Validation IoU: 0.6515, Validation Dice: 0.7889 , Validation Accuracy: 0.9505
# Epoch 154, Train Loss: 0.1280, Train IoU: 0.6446, Train Dice: 0.7838 , Train Accuracy: 0.9507, Validation Loss: 0.1276, Validation IoU: 0.6516, Validation Dice: 0.7890 , Validation Accuracy: 0.9507
# Epoch 155, Train Loss: 0.1300, Train IoU: 0.6415, Train Dice: 0.7814 , Train Accuracy: 0.9504, Validation Loss: 0.1273, Validation IoU: 0.6514, Validation Dice: 0.7888 , Validation Accuracy: 0.9508
# Epoch 156, Train Loss: 0.1292, Train IoU: 0.6422, Train Dice: 0.7817 , Train Accuracy: 0.9505, Validation Loss: 0.1277, Validation IoU: 0.6502, Validation Dice: 0.7879 , Validation Accuracy: 0.9506
# Epoch 157, Train Loss: 0.1267, Train IoU: 0.6481, Train Dice: 0.7862 , Train Accuracy: 0.9514, Validation Loss: 0.1259, Validation IoU: 0.6569, Validation Dice: 0.7929 , Validation Accuracy: 0.9515
# Epoch 158, Train Loss: 0.1275, Train IoU: 0.6456, Train Dice: 0.7843 , Train Accuracy: 0.9511, Validation Loss: 0.1271, Validation IoU: 0.6499, Validation Dice: 0.7877 , Validation Accuracy: 0.9509
# Epoch 159, Train Loss: 0.1276, Train IoU: 0.6476, Train Dice: 0.7858 , Train Accuracy: 0.9511, Validation Loss: 0.1257, Validation IoU: 0.6549, Validation Dice: 0.7914 , Validation Accuracy: 0.9514
# Epoch 160, Train Loss: 0.1267, Train IoU: 0.6498, Train Dice: 0.7876 , Train Accuracy: 0.9514, Validation Loss: 0.1248, Validation IoU: 0.6614, Validation Dice: 0.7961 , Validation Accuracy: 0.9519
# Epoch 161, Train Loss: 0.1276, Train IoU: 0.6478, Train Dice: 0.7859 , Train Accuracy: 0.9510, Validation Loss: 0.1241, Validation IoU: 0.6608, Validation Dice: 0.7957 , Validation Accuracy: 0.9521
# Epoch 162, Train Loss: 0.1259, Train IoU: 0.6501, Train Dice: 0.7876 , Train Accuracy: 0.9518, Validation Loss: 0.1255, Validation IoU: 0.6554, Validation Dice: 0.7917 , Validation Accuracy: 0.9517
# Epoch 163, Train Loss: 0.1270, Train IoU: 0.6458, Train Dice: 0.7842 , Train Accuracy: 0.9513, Validation Loss: 0.1259, Validation IoU: 0.6499, Validation Dice: 0.7877 , Validation Accuracy: 0.9515
# Epoch 164, Train Loss: 0.1276, Train IoU: 0.6434, Train Dice: 0.7829 , Train Accuracy: 0.9511, Validation Loss: 0.1260, Validation IoU: 0.6541, Validation Dice: 0.7907 , Validation Accuracy: 0.9514
# Epoch 165, Train Loss: 0.1257, Train IoU: 0.6520, Train Dice: 0.7892 , Train Accuracy: 0.9514, Validation Loss: 0.1248, Validation IoU: 0.6592, Validation Dice: 0.7945 , Validation Accuracy: 0.9518
# Epoch 166, Train Loss: 0.1261, Train IoU: 0.6472, Train Dice: 0.7857 , Train Accuracy: 0.9512, Validation Loss: 0.1251, Validation IoU: 0.6555, Validation Dice: 0.7918 , Validation Accuracy: 0.9514
# Epoch 167, Train Loss: 0.1261, Train IoU: 0.6496, Train Dice: 0.7872 , Train Accuracy: 0.9515, Validation Loss: 0.1239, Validation IoU: 0.6573, Validation Dice: 0.7932 , Validation Accuracy: 0.9521
# Epoch 168, Train Loss: 0.1262, Train IoU: 0.6473, Train Dice: 0.7856 , Train Accuracy: 0.9513, Validation Loss: 0.1249, Validation IoU: 0.6568, Validation Dice: 0.7928 , Validation Accuracy: 0.9515
# Epoch 169, Train Loss: 0.1259, Train IoU: 0.6503, Train Dice: 0.7880 , Train Accuracy: 0.9514, Validation Loss: 0.1237, Validation IoU: 0.6582, Validation Dice: 0.7938 , Validation Accuracy: 0.9520
# Epoch 170, Train Loss: 0.1248, Train IoU: 0.6522, Train Dice: 0.7892 , Train Accuracy: 0.9520, Validation Loss: 0.1228, Validation IoU: 0.6618, Validation Dice: 0.7965 , Validation Accuracy: 0.9522
# Epoch 171, Train Loss: 0.1235, Train IoU: 0.6545, Train Dice: 0.7910 , Train Accuracy: 0.9525, Validation Loss: 0.1235, Validation IoU: 0.6578, Validation Dice: 0.7935 , Validation Accuracy: 0.9520
# Epoch 172, Train Loss: 0.1258, Train IoU: 0.6511, Train Dice: 0.7884 , Train Accuracy: 0.9517, Validation Loss: 0.1246, Validation IoU: 0.6565, Validation Dice: 0.7926 , Validation Accuracy: 0.9517
# Epoch 173, Train Loss: 0.1294, Train IoU: 0.6429, Train Dice: 0.7823 , Train Accuracy: 0.9506, Validation Loss: 0.1261, Validation IoU: 0.6504, Validation Dice: 0.7880 , Validation Accuracy: 0.9512
# Epoch 174, Train Loss: 0.1267, Train IoU: 0.6474, Train Dice: 0.7857 , Train Accuracy: 0.9513, Validation Loss: 0.1241, Validation IoU: 0.6593, Validation Dice: 0.7946 , Validation Accuracy: 0.9519
# Epoch 175, Train Loss: 0.1237, Train IoU: 0.6566, Train Dice: 0.7925 , Train Accuracy: 0.9525, Validation Loss: 0.1253, Validation IoU: 0.6597, Validation Dice: 0.7948 , Validation Accuracy: 0.9515
# Epoch 176, Train Loss: 0.1236, Train IoU: 0.6555, Train Dice: 0.7918 , Train Accuracy: 0.9527, Validation Loss: 0.1227, Validation IoU: 0.6615, Validation Dice: 0.7962 , Validation Accuracy: 0.9524
# Epoch 177, Train Loss: 0.1244, Train IoU: 0.6568, Train Dice: 0.7928 , Train Accuracy: 0.9523, Validation Loss: 0.1225, Validation IoU: 0.6631, Validation Dice: 0.7973 , Validation Accuracy: 0.9527
# Epoch 178, Train Loss: 0.1225, Train IoU: 0.6575, Train Dice: 0.7931 , Train Accuracy: 0.9529, Validation Loss: 0.1214, Validation IoU: 0.6644, Validation Dice: 0.7983 , Validation Accuracy: 0.9530
# Epoch 179, Train Loss: 0.1259, Train IoU: 0.6518, Train Dice: 0.7889 , Train Accuracy: 0.9517, Validation Loss: 0.1232, Validation IoU: 0.6671, Validation Dice: 0.8002 , Validation Accuracy: 0.9522
# Epoch 180, Train Loss: 0.1249, Train IoU: 0.6506, Train Dice: 0.7880 , Train Accuracy: 0.9517, Validation Loss: 0.1223, Validation IoU: 0.6658, Validation Dice: 0.7993 , Validation Accuracy: 0.9526
# Epoch 181, Train Loss: 0.1224, Train IoU: 0.6585, Train Dice: 0.7939 , Train Accuracy: 0.9527, Validation Loss: 0.1226, Validation IoU: 0.6653, Validation Dice: 0.7990 , Validation Accuracy: 0.9522
# Epoch 182, Train Loss: 0.1262, Train IoU: 0.6463, Train Dice: 0.7848 , Train Accuracy: 0.9511, Validation Loss: 0.1222, Validation IoU: 0.6630, Validation Dice: 0.7973 , Validation Accuracy: 0.9525
# Epoch 183, Train Loss: 0.1216, Train IoU: 0.6598, Train Dice: 0.7949 , Train Accuracy: 0.9532, Validation Loss: 0.1223, Validation IoU: 0.6604, Validation Dice: 0.7954 , Validation Accuracy: 0.9525
# Epoch 184, Train Loss: 0.1231, Train IoU: 0.6559, Train Dice: 0.7920 , Train Accuracy: 0.9527, Validation Loss: 0.1229, Validation IoU: 0.6634, Validation Dice: 0.7976 , Validation Accuracy: 0.9526
# Epoch 185, Train Loss: 0.1262, Train IoU: 0.6501, Train Dice: 0.7874 , Train Accuracy: 0.9519, Validation Loss: 0.1241, Validation IoU: 0.6611, Validation Dice: 0.7959 , Validation Accuracy: 0.9519
# Epoch 186, Train Loss: 0.1252, Train IoU: 0.6556, Train Dice: 0.7917 , Train Accuracy: 0.9521, Validation Loss: 0.1247, Validation IoU: 0.6602, Validation Dice: 0.7951 , Validation Accuracy: 0.9516
# Epoch 187, Train Loss: 0.1233, Train IoU: 0.6533, Train Dice: 0.7901 , Train Accuracy: 0.9527, Validation Loss: 0.1251, Validation IoU: 0.6540, Validation Dice: 0.7906 , Validation Accuracy: 0.9518
# Epoch 188, Train Loss: 0.1243, Train IoU: 0.6539, Train Dice: 0.7904 , Train Accuracy: 0.9522, Validation Loss: 0.1222, Validation IoU: 0.6641, Validation Dice: 0.7980 , Validation Accuracy: 0.9525
# Epoch 189, Train Loss: 0.1227, Train IoU: 0.6556, Train Dice: 0.7918 , Train Accuracy: 0.9525, Validation Loss: 0.1212, Validation IoU: 0.6657, Validation Dice: 0.7993 , Validation Accuracy: 0.9530
# Epoch 190, Train Loss: 0.1212, Train IoU: 0.6611, Train Dice: 0.7958 , Train Accuracy: 0.9531, Validation Loss: 0.1197, Validation IoU: 0.6747, Validation Dice: 0.8057 , Validation Accuracy: 0.9534
# Epoch 191, Train Loss: 0.1213, Train IoU: 0.6624, Train Dice: 0.7967 , Train Accuracy: 0.9534, Validation Loss: 0.1188, Validation IoU: 0.6740, Validation Dice: 0.8052 , Validation Accuracy: 0.9539
# Epoch 192, Train Loss: 0.1199, Train IoU: 0.6650, Train Dice: 0.7986 , Train Accuracy: 0.9535, Validation Loss: 0.1195, Validation IoU: 0.6722, Validation Dice: 0.8039 , Validation Accuracy: 0.9535
# Epoch 193, Train Loss: 0.1228, Train IoU: 0.6584, Train Dice: 0.7938 , Train Accuracy: 0.9527, Validation Loss: 0.1207, Validation IoU: 0.6709, Validation Dice: 0.8030 , Validation Accuracy: 0.9535
# Epoch 194, Train Loss: 0.1209, Train IoU: 0.6638, Train Dice: 0.7977 , Train Accuracy: 0.9536, Validation Loss: 0.1203, Validation IoU: 0.6712, Validation Dice: 0.8032 , Validation Accuracy: 0.9535
# Epoch 195, Train Loss: 0.1204, Train IoU: 0.6603, Train Dice: 0.7953 , Train Accuracy: 0.9531, Validation Loss: 0.1201, Validation IoU: 0.6684, Validation Dice: 0.8012 , Validation Accuracy: 0.9534
# Epoch 196, Train Loss: 0.1196, Train IoU: 0.6655, Train Dice: 0.7988 , Train Accuracy: 0.9540, Validation Loss: 0.1213, Validation IoU: 0.6656, Validation Dice: 0.7991 , Validation Accuracy: 0.9528
# Epoch 197, Train Loss: 0.1189, Train IoU: 0.6668, Train Dice: 0.8000 , Train Accuracy: 0.9538, Validation Loss: 0.1175, Validation IoU: 0.6729, Validation Dice: 0.8044 , Validation Accuracy: 0.9542
# Epoch 198, Train Loss: 0.1191, Train IoU: 0.6664, Train Dice: 0.7996 , Train Accuracy: 0.9536, Validation Loss: 0.1193, Validation IoU: 0.6702, Validation Dice: 0.8024 , Validation Accuracy: 0.9534
# Epoch 199, Train Loss: 0.1191, Train IoU: 0.6670, Train Dice: 0.7999 , Train Accuracy: 0.9540, Validation Loss: 0.1171, Validation IoU: 0.6803, Validation Dice: 0.8097 , Validation Accuracy: 0.9545
# Epoch 200, Train Loss: 0.1207, Train IoU: 0.6627, Train Dice: 0.7969 , Train Accuracy: 0.9537, Validation Loss: 0.1187, Validation IoU: 0.6725, Validation Dice: 0.8041 , Validation Accuracy: 0.9539
# Epoch 201, Train Loss: 0.1198, Train IoU: 0.6673, Train Dice: 0.8003 , Train Accuracy: 0.9538, Validation Loss: 0.1182, Validation IoU: 0.6780, Validation Dice: 0.8081 , Validation Accuracy: 0.9541
# Epoch 202, Train Loss: 0.1212, Train IoU: 0.6600, Train Dice: 0.7948 , Train Accuracy: 0.9531, Validation Loss: 0.1198, Validation IoU: 0.6678, Validation Dice: 0.8007 , Validation Accuracy: 0.9532
# Epoch 203, Train Loss: 0.1187, Train IoU: 0.6680, Train Dice: 0.8008 , Train Accuracy: 0.9540, Validation Loss: 0.1193, Validation IoU: 0.6764, Validation Dice: 0.8069 , Validation Accuracy: 0.9536
# Epoch 204, Train Loss: 0.1220, Train IoU: 0.6603, Train Dice: 0.7953 , Train Accuracy: 0.9529, Validation Loss: 0.1189, Validation IoU: 0.6756, Validation Dice: 0.8063 , Validation Accuracy: 0.9537
# Epoch 205, Train Loss: 0.1185, Train IoU: 0.6683, Train Dice: 0.8010 , Train Accuracy: 0.9542, Validation Loss: 0.1188, Validation IoU: 0.6718, Validation Dice: 0.8036 , Validation Accuracy: 0.9537
# Epoch 206, Train Loss: 0.1167, Train IoU: 0.6720, Train Dice: 0.8037 , Train Accuracy: 0.9546, Validation Loss: 0.1171, Validation IoU: 0.6769, Validation Dice: 0.8073 , Validation Accuracy: 0.9544
# Epoch 207, Train Loss: 0.1182, Train IoU: 0.6674, Train Dice: 0.8004 , Train Accuracy: 0.9541, Validation Loss: 0.1168, Validation IoU: 0.6767, Validation Dice: 0.8072 , Validation Accuracy: 0.9544
# Epoch 208, Train Loss: 0.1202, Train IoU: 0.6662, Train Dice: 0.7991 , Train Accuracy: 0.9537, Validation Loss: 0.1160, Validation IoU: 0.6820, Validation Dice: 0.8109 , Validation Accuracy: 0.9548
# Epoch 209, Train Loss: 0.1191, Train IoU: 0.6662, Train Dice: 0.7994 , Train Accuracy: 0.9539, Validation Loss: 0.1163, Validation IoU: 0.6763, Validation Dice: 0.8069 , Validation Accuracy: 0.9546
# Epoch 210, Train Loss: 0.1164, Train IoU: 0.6735, Train Dice: 0.8048 , Train Accuracy: 0.9549, Validation Loss: 0.1159, Validation IoU: 0.6787, Validation Dice: 0.8085 , Validation Accuracy: 0.9547
# Epoch 211, Train Loss: 0.1164, Train IoU: 0.6721, Train Dice: 0.8036 , Train Accuracy: 0.9548, Validation Loss: 0.1157, Validation IoU: 0.6790, Validation Dice: 0.8088 , Validation Accuracy: 0.9549
# Epoch 212, Train Loss: 0.1162, Train IoU: 0.6720, Train Dice: 0.8035 , Train Accuracy: 0.9548, Validation Loss: 0.1149, Validation IoU: 0.6847, Validation Dice: 0.8128 , Validation Accuracy: 0.9551
# Epoch 213, Train Loss: 0.1150, Train IoU: 0.6773, Train Dice: 0.8075 , Train Accuracy: 0.9555, Validation Loss: 0.1147, Validation IoU: 0.6833, Validation Dice: 0.8118 , Validation Accuracy: 0.9553
# Epoch 214, Train Loss: 0.1178, Train IoU: 0.6697, Train Dice: 0.8020 , Train Accuracy: 0.9543, Validation Loss: 0.1154, Validation IoU: 0.6798, Validation Dice: 0.8093 , Validation Accuracy: 0.9548
# Epoch 215, Train Loss: 0.1194, Train IoU: 0.6656, Train Dice: 0.7990 , Train Accuracy: 0.9538, Validation Loss: 0.1196, Validation IoU: 0.6713, Validation Dice: 0.8032 , Validation Accuracy: 0.9532
# Epoch 216, Train Loss: 0.1181, Train IoU: 0.6656, Train Dice: 0.7990 , Train Accuracy: 0.9539, Validation Loss: 0.1186, Validation IoU: 0.6666, Validation Dice: 0.7998 , Validation Accuracy: 0.9535
# Epoch 217, Train Loss: 0.1171, Train IoU: 0.6672, Train Dice: 0.8003 , Train Accuracy: 0.9542, Validation Loss: 0.1182, Validation IoU: 0.6699, Validation Dice: 0.8022 , Validation Accuracy: 0.9535
# Epoch 218, Train Loss: 0.1147, Train IoU: 0.6784, Train Dice: 0.8082 , Train Accuracy: 0.9553, Validation Loss: 0.1143, Validation IoU: 0.6852, Validation Dice: 0.8132 , Validation Accuracy: 0.9553
# Epoch 219, Train Loss: 0.1163, Train IoU: 0.6758, Train Dice: 0.8063 , Train Accuracy: 0.9551, Validation Loss: 0.1142, Validation IoU: 0.6862, Validation Dice: 0.8139 , Validation Accuracy: 0.9554
# Epoch 220, Train Loss: 0.1175, Train IoU: 0.6690, Train Dice: 0.8014 , Train Accuracy: 0.9543, Validation Loss: 0.1155, Validation IoU: 0.6818, Validation Dice: 0.8108 , Validation Accuracy: 0.9550
# Epoch 221, Train Loss: 0.1177, Train IoU: 0.6685, Train Dice: 0.8009 , Train Accuracy: 0.9543, Validation Loss: 0.1173, Validation IoU: 0.6734, Validation Dice: 0.8047 , Validation Accuracy: 0.9540
# Epoch 222, Train Loss: 0.1150, Train IoU: 0.6755, Train Dice: 0.8061 , Train Accuracy: 0.9552, Validation Loss: 0.1141, Validation IoU: 0.6846, Validation Dice: 0.8127 , Validation Accuracy: 0.9554
# Epoch 223, Train Loss: 0.1153, Train IoU: 0.6765, Train Dice: 0.8069 , Train Accuracy: 0.9552, Validation Loss: 0.1137, Validation IoU: 0.6859, Validation Dice: 0.8137 , Validation Accuracy: 0.9556
# Epoch 224, Train Loss: 0.1171, Train IoU: 0.6736, Train Dice: 0.8048 , Train Accuracy: 0.9542, Validation Loss: 0.1167, Validation IoU: 0.6815, Validation Dice: 0.8104 , Validation Accuracy: 0.9544
# Epoch 225, Train Loss: 0.1170, Train IoU: 0.6700, Train Dice: 0.8022 , Train Accuracy: 0.9545, Validation Loss: 0.1146, Validation IoU: 0.6805, Validation Dice: 0.8098 , Validation Accuracy: 0.9552
# Epoch 226, Train Loss: 0.1174, Train IoU: 0.6683, Train Dice: 0.8011 , Train Accuracy: 0.9544, Validation Loss: 0.1153, Validation IoU: 0.6775, Validation Dice: 0.8077 , Validation Accuracy: 0.9549
# Epoch 227, Train Loss: 0.1158, Train IoU: 0.6742, Train Dice: 0.8051 , Train Accuracy: 0.9551, Validation Loss: 0.1151, Validation IoU: 0.6792, Validation Dice: 0.8088 , Validation Accuracy: 0.9550
# Epoch 228, Train Loss: 0.1169, Train IoU: 0.6714, Train Dice: 0.8032 , Train Accuracy: 0.9545, Validation Loss: 0.1158, Validation IoU: 0.6812, Validation Dice: 0.8104 , Validation Accuracy: 0.9547
# Epoch 229, Train Loss: 0.1171, Train IoU: 0.6695, Train Dice: 0.8019 , Train Accuracy: 0.9545, Validation Loss: 0.1145, Validation IoU: 0.6803, Validation Dice: 0.8097 , Validation Accuracy: 0.9553
# Epoch 230, Train Loss: 0.1143, Train IoU: 0.6779, Train Dice: 0.8079 , Train Accuracy: 0.9555, Validation Loss: 0.1133, Validation IoU: 0.6857, Validation Dice: 0.8135 , Validation Accuracy: 0.9556
# Epoch 231, Train Loss: 0.1147, Train IoU: 0.6771, Train Dice: 0.8073 , Train Accuracy: 0.9551, Validation Loss: 0.1136, Validation IoU: 0.6860, Validation Dice: 0.8137 , Validation Accuracy: 0.9553
# Epoch 232, Train Loss: 0.1136, Train IoU: 0.6780, Train Dice: 0.8079 , Train Accuracy: 0.9558, Validation Loss: 0.1118, Validation IoU: 0.6882, Validation Dice: 0.8153 , Validation Accuracy: 0.9563
# Epoch 233, Train Loss: 0.1115, Train IoU: 0.6856, Train Dice: 0.8134 , Train Accuracy: 0.9564, Validation Loss: 0.1131, Validation IoU: 0.6870, Validation Dice: 0.8144 , Validation Accuracy: 0.9556
# Epoch 234, Train Loss: 0.1165, Train IoU: 0.6730, Train Dice: 0.8043 , Train Accuracy: 0.9548, Validation Loss: 0.1137, Validation IoU: 0.6836, Validation Dice: 0.8120 , Validation Accuracy: 0.9554
# Epoch 235, Train Loss: 0.1128, Train IoU: 0.6796, Train Dice: 0.8092 , Train Accuracy: 0.9560, Validation Loss: 0.1124, Validation IoU: 0.6885, Validation Dice: 0.8155 , Validation Accuracy: 0.9560
# Epoch 236, Train Loss: 0.1124, Train IoU: 0.6810, Train Dice: 0.8100 , Train Accuracy: 0.9561, Validation Loss: 0.1117, Validation IoU: 0.6942, Validation Dice: 0.8195 , Validation Accuracy: 0.9562
# Epoch 237, Train Loss: 0.1155, Train IoU: 0.6765, Train Dice: 0.8068 , Train Accuracy: 0.9551, Validation Loss: 0.1132, Validation IoU: 0.6853, Validation Dice: 0.8132 , Validation Accuracy: 0.9557
# Epoch 238, Train Loss: 0.1121, Train IoU: 0.6816, Train Dice: 0.8105 , Train Accuracy: 0.9561, Validation Loss: 0.1119, Validation IoU: 0.6883, Validation Dice: 0.8154 , Validation Accuracy: 0.9562
# Epoch 239, Train Loss: 0.1136, Train IoU: 0.6809, Train Dice: 0.8100 , Train Accuracy: 0.9556, Validation Loss: 0.1102, Validation IoU: 0.6955, Validation Dice: 0.8204 , Validation Accuracy: 0.9568
# Epoch 240, Train Loss: 0.1126, Train IoU: 0.6804, Train Dice: 0.8096 , Train Accuracy: 0.9560, Validation Loss: 0.1112, Validation IoU: 0.6877, Validation Dice: 0.8149 , Validation Accuracy: 0.9564
# Epoch 241, Train Loss: 0.1125, Train IoU: 0.6819, Train Dice: 0.8107 , Train Accuracy: 0.9559, Validation Loss: 0.1117, Validation IoU: 0.6880, Validation Dice: 0.8151 , Validation Accuracy: 0.9560
# Epoch 242, Train Loss: 0.1114, Train IoU: 0.6841, Train Dice: 0.8122 , Train Accuracy: 0.9562, Validation Loss: 0.1112, Validation IoU: 0.6896, Validation Dice: 0.8162 , Validation Accuracy: 0.9563
# ...
# Epoch 721, Train Loss: 0.0575, Train IoU: 0.8151, Train Dice: 0.8979 , Train Accuracy: 0.9752, Validation Loss: 0.0502, Validation IoU: 0.8482, Validation Dice: 0.9177 , Validation Accuracy: 0.9795
# Epoch 722, Train Loss: 0.0593, Train IoU: 0.8095, Train Dice: 0.8945 , Train Accuracy: 0.9744, Validation Loss: 0.0500, Validation IoU: 0.8493, Validation Dice: 0.9183 , Validation Accuracy: 0.9797
# Epoch 723, Train Loss: 0.0541, Train IoU: 0.8261, Train Dice: 0.9047 , Train Accuracy: 0.9767, Validation Loss: 0.0495, Validation IoU: 0.8500, Validation Dice: 0.9188 , Validation Accuracy: 0.9797
# Epoch 724, Train Loss: 0.0587, Train IoU: 0.8115, Train Dice: 0.8957 , Train Accuracy: 0.9747, Validation Loss: 0.0497, Validation IoU: 0.8492, Validation Dice: 0.9183 , Validation Accuracy: 0.9797
# Epoch 725, Train Loss: 0.0596, Train IoU: 0.8094, Train Dice: 0.8945 , Train Accuracy: 0.9743, Validation Loss: 0.0506, Validation IoU: 0.8463, Validation Dice: 0.9166 , Validation Accuracy: 0.9793
# Epoch 726, Train Loss: 0.0591, Train IoU: 0.8112, Train Dice: 0.8953 , Train Accuracy: 0.9746, Validation Loss: 0.0504, Validation IoU: 0.8479, Validation Dice: 0.9176 , Validation Accuracy: 0.9794
# Epoch 727, Train Loss: 0.0579, Train IoU: 0.8150, Train Dice: 0.8980 , Train Accuracy: 0.9752, Validation Loss: 0.0512, Validation IoU: 0.8441, Validation Dice: 0.9153 , Validation Accuracy: 0.9789
# Epoch 728, Train Loss: 0.0577, Train IoU: 0.8158, Train Dice: 0.8984 , Train Accuracy: 0.9753, Validation Loss: 0.0509, Validation IoU: 0.8449, Validation Dice: 0.9158 , Validation Accuracy: 0.9790
# Epoch 729, Train Loss: 0.0556, Train IoU: 0.8218, Train Dice: 0.9021 , Train Accuracy: 0.9762, Validation Loss: 0.0503, Validation IoU: 0.8454, Validation Dice: 0.9161 , Validation Accuracy: 0.9793
# Epoch 730, Train Loss: 0.0563, Train IoU: 0.8197, Train Dice: 0.9008 , Train Accuracy: 0.9759, Validation Loss: 0.0499, Validation IoU: 0.8500, Validation Dice: 0.9188 , Validation Accuracy: 0.9795
# Epoch 731, Train Loss: 0.0589, Train IoU: 0.8113, Train Dice: 0.8957 , Train Accuracy: 0.9747, Validation Loss: 0.0512, Validation IoU: 0.8434, Validation Dice: 0.9149 , Validation Accuracy: 0.9788
# Epoch 732, Train Loss: 0.0585, Train IoU: 0.8119, Train Dice: 0.8960 , Train Accuracy: 0.9749, Validation Loss: 0.0515, Validation IoU: 0.8428, Validation Dice: 0.9146 , Validation Accuracy: 0.9787
# Epoch 733, Train Loss: 0.0591, Train IoU: 0.8117, Train Dice: 0.8958 , Train Accuracy: 0.9748, Validation Loss: 0.0515, Validation IoU: 0.8434, Validation Dice: 0.9149 , Validation Accuracy: 0.9788
# Epoch 734, Train Loss: 0.0587, Train IoU: 0.8116, Train Dice: 0.8958 , Train Accuracy: 0.9747, Validation Loss: 0.0518, Validation IoU: 0.8429, Validation Dice: 0.9146 , Validation Accuracy: 0.9788
# Epoch 735, Train Loss: 0.0598, Train IoU: 0.8077, Train Dice: 0.8935 , Train Accuracy: 0.9741, Validation Loss: 0.0519, Validation IoU: 0.8414, Validation Dice: 0.9137 , Validation Accuracy: 0.9785
# Epoch 736, Train Loss: 0.0572, Train IoU: 0.8168, Train Dice: 0.8990 , Train Accuracy: 0.9755, Validation Loss: 0.0505, Validation IoU: 0.8472, Validation Dice: 0.9171 , Validation Accuracy: 0.9792
# Epoch 737, Train Loss: 0.0576, Train IoU: 0.8165, Train Dice: 0.8987 , Train Accuracy: 0.9753, Validation Loss: 0.0510, Validation IoU: 0.8435, Validation Dice: 0.9150 , Validation Accuracy: 0.9789
# Epoch 738, Train Loss: 0.0558, Train IoU: 0.8215, Train Dice: 0.9018 , Train Accuracy: 0.9761, Validation Loss: 0.0499, Validation IoU: 0.8492, Validation Dice: 0.9183 , Validation Accuracy: 0.9794
# Epoch 739, Train Loss: 0.0573, Train IoU: 0.8168, Train Dice: 0.8989 , Train Accuracy: 0.9754, Validation Loss: 0.0496, Validation IoU: 0.8491, Validation Dice: 0.9183 , Validation Accuracy: 0.9796
# Epoch 740, Train Loss: 0.0585, Train IoU: 0.8117, Train Dice: 0.8959 , Train Accuracy: 0.9748, Validation Loss: 0.0493, Validation IoU: 0.8498, Validation Dice: 0.9187 , Validation Accuracy: 0.9797
# Epoch 741, Train Loss: 0.0574, Train IoU: 0.8170, Train Dice: 0.8991 , Train Accuracy: 0.9754, Validation Loss: 0.0495, Validation IoU: 0.8487, Validation Dice: 0.9180 , Validation Accuracy: 0.9796
# Epoch 742, Train Loss: 0.0562, Train IoU: 0.8200, Train Dice: 0.9010 , Train Accuracy: 0.9758, Validation Loss: 0.0491, Validation IoU: 0.8507, Validation Dice: 0.9192 , Validation Accuracy: 0.9798
# Epoch 743, Train Loss: 0.0588, Train IoU: 0.8131, Train Dice: 0.8968 , Train Accuracy: 0.9750, Validation Loss: 0.0493, Validation IoU: 0.8484, Validation Dice: 0.9178 , Validation Accuracy: 0.9797
# Epoch 744, Train Loss: 0.0569, Train IoU: 0.8171, Train Dice: 0.8992 , Train Accuracy: 0.9756, Validation Loss: 0.0488, Validation IoU: 0.8517, Validation Dice: 0.9197 , Validation Accuracy: 0.9800
# Epoch 745, Train Loss: 0.0543, Train IoU: 0.8247, Train Dice: 0.9038 , Train Accuracy: 0.9766, Validation Loss: 0.0488, Validation IoU: 0.8502, Validation Dice: 0.9189 , Validation Accuracy: 0.9799
# Epoch 746, Train Loss: 0.0585, Train IoU: 0.8110, Train Dice: 0.8955 , Train Accuracy: 0.9747, Validation Loss: 0.0501, Validation IoU: 0.8476, Validation Dice: 0.9174 , Validation Accuracy: 0.9792
# Epoch 747, Train Loss: 0.0579, Train IoU: 0.8136, Train Dice: 0.8970 , Train Accuracy: 0.9751, Validation Loss: 0.0496, Validation IoU: 0.8475, Validation Dice: 0.9173 , Validation Accuracy: 0.9795
# Epoch 748, Train Loss: 0.0574, Train IoU: 0.8150, Train Dice: 0.8979 , Train Accuracy: 0.9754, Validation Loss: 0.0491, Validation IoU: 0.8498, Validation Dice: 0.9186 , Validation Accuracy: 0.9798
# Epoch 749, Train Loss: 0.0583, Train IoU: 0.8129, Train Dice: 0.8966 , Train Accuracy: 0.9750, Validation Loss: 0.0494, Validation IoU: 0.8502, Validation Dice: 0.9189 , Validation Accuracy: 0.9796
# Epoch 750, Train Loss: 0.0571, Train IoU: 0.8171, Train Dice: 0.8992 , Train Accuracy: 0.9756, Validation Loss: 0.0503, Validation IoU: 0.8455, Validation Dice: 0.9161 , Validation Accuracy: 0.9792
# Epoch 751, Train Loss: 0.0574, Train IoU: 0.8166, Train Dice: 0.8989 , Train Accuracy: 0.9754, Validation Loss: 0.0492, Validation IoU: 0.8488, Validation Dice: 0.9181 , Validation Accuracy: 0.9797
# Epoch 752, Train Loss: 0.0579, Train IoU: 0.8147, Train Dice: 0.8977 , Train Accuracy: 0.9751, Validation Loss: 0.0498, Validation IoU: 0.8477, Validation Dice: 0.9174 , Validation Accuracy: 0.9794
# Epoch 753, Train Loss: 0.0551, Train IoU: 0.8230, Train Dice: 0.9027 , Train Accuracy: 0.9764, Validation Loss: 0.0492, Validation IoU: 0.8497, Validation Dice: 0.9186 , Validation Accuracy: 0.9797
# Epoch 754, Train Loss: 0.0548, Train IoU: 0.8232, Train Dice: 0.9029 , Train Accuracy: 0.9764, Validation Loss: 0.0488, Validation IoU: 0.8518, Validation Dice: 0.9198 , Validation Accuracy: 0.9798
# Epoch 755, Train Loss: 0.0568, Train IoU: 0.8183, Train Dice: 0.8998 , Train Accuracy: 0.9756, Validation Loss: 0.0492, Validation IoU: 0.8507, Validation Dice: 0.9192 , Validation Accuracy: 0.9797
# Epoch 756, Train Loss: 0.0569, Train IoU: 0.8181, Train Dice: 0.8998 , Train Accuracy: 0.9757, Validation Loss: 0.0488, Validation IoU: 0.8513, Validation Dice: 0.9195 , Validation Accuracy: 0.9800
# Epoch 757, Train Loss: 0.0584, Train IoU: 0.8131, Train Dice: 0.8968 , Train Accuracy: 0.9750, Validation Loss: 0.0498, Validation IoU: 0.8489, Validation Dice: 0.9181 , Validation Accuracy: 0.9796
# Epoch 758, Train Loss: 0.0544, Train IoU: 0.8265, Train Dice: 0.9049 , Train Accuracy: 0.9768, Validation Loss: 0.0489, Validation IoU: 0.8502, Validation Dice: 0.9189 , Validation Accuracy: 0.9798
# Epoch 759, Train Loss: 0.0540, Train IoU: 0.8273, Train Dice: 0.9053 , Train Accuracy: 0.9769, Validation Loss: 0.0486, Validation IoU: 0.8526, Validation Dice: 0.9203 , Validation Accuracy: 0.9800
# Epoch 760, Train Loss: 0.0575, Train IoU: 0.8155, Train Dice: 0.8982 , Train Accuracy: 0.9753, Validation Loss: 0.0497, Validation IoU: 0.8473, Validation Dice: 0.9172 , Validation Accuracy: 0.9795
# Epoch 761, Train Loss: 0.0547, Train IoU: 0.8245, Train Dice: 0.9036 , Train Accuracy: 0.9766, Validation Loss: 0.0492, Validation IoU: 0.8489, Validation Dice: 0.9181 , Validation Accuracy: 0.9797
# Epoch 762, Train Loss: 0.0530, Train IoU: 0.8302, Train Dice: 0.9070 , Train Accuracy: 0.9775, Validation Loss: 0.0486, Validation IoU: 0.8518, Validation Dice: 0.9198 , Validation Accuracy: 0.9799
# Epoch 763, Train Loss: 0.0548, Train IoU: 0.8253, Train Dice: 0.9041 , Train Accuracy: 0.9766, Validation Loss: 0.0488, Validation IoU: 0.8501, Validation Dice: 0.9188 , Validation Accuracy: 0.9798
# Epoch 764, Train Loss: 0.0560, Train IoU: 0.8218, Train Dice: 0.9020 , Train Accuracy: 0.9761, Validation Loss: 0.0488, Validation IoU: 0.8516, Validation Dice: 0.9197 , Validation Accuracy: 0.9799
# Epoch 765, Train Loss: 0.0592, Train IoU: 0.8105, Train Dice: 0.8952 , Train Accuracy: 0.9745, Validation Loss: 0.0491, Validation IoU: 0.8493, Validation Dice: 0.9183 , Validation Accuracy: 0.9797
# Epoch 766, Train Loss: 0.0539, Train IoU: 0.8270, Train Dice: 0.9050 , Train Accuracy: 0.9769, Validation Loss: 0.0485, Validation IoU: 0.8523, Validation Dice: 0.9201 , Validation Accuracy: 0.9801
# Epoch 767, Train Loss: 0.0542, Train IoU: 0.8255, Train Dice: 0.9041 , Train Accuracy: 0.9767, Validation Loss: 0.0481, Validation IoU: 0.8528, Validation Dice: 0.9204 , Validation Accuracy: 0.9802
# Epoch 768, Train Loss: 0.0531, Train IoU: 0.8285, Train Dice: 0.9061 , Train Accuracy: 0.9772, Validation Loss: 0.0481, Validation IoU: 0.8522, Validation Dice: 0.9200 , Validation Accuracy: 0.9802
# Epoch 769, Train Loss: 0.0524, Train IoU: 0.8326, Train Dice: 0.9084 , Train Accuracy: 0.9776, Validation Loss: 0.0482, Validation IoU: 0.8530, Validation Dice: 0.9205 , Validation Accuracy: 0.9801
# Epoch 770, Train Loss: 0.0578, Train IoU: 0.8150, Train Dice: 0.8978 , Train Accuracy: 0.9752, Validation Loss: 0.0483, Validation IoU: 0.8516, Validation Dice: 0.9197 , Validation Accuracy: 0.9802
# Epoch 771, Train Loss: 0.0544, Train IoU: 0.8255, Train Dice: 0.9042 , Train Accuracy: 0.9767, Validation Loss: 0.0482, Validation IoU: 0.8520, Validation Dice: 0.9199 , Validation Accuracy: 0.9801
# Epoch 772, Train Loss: 0.0535, Train IoU: 0.8283, Train Dice: 0.9059 , Train Accuracy: 0.9771, Validation Loss: 0.0476, Validation IoU: 0.8548, Validation Dice: 0.9216 , Validation Accuracy: 0.9804
# Epoch 773, Train Loss: 0.0542, Train IoU: 0.8261, Train Dice: 0.9046 , Train Accuracy: 0.9768, Validation Loss: 0.0478, Validation IoU: 0.8547, Validation Dice: 0.9215 , Validation Accuracy: 0.9805
# Epoch 774, Train Loss: 0.0564, Train IoU: 0.8192, Train Dice: 0.9003 , Train Accuracy: 0.9759, Validation Loss: 0.0479, Validation IoU: 0.8541, Validation Dice: 0.9212 , Validation Accuracy: 0.9804
# Epoch 775, Train Loss: 0.0555, Train IoU: 0.8215, Train Dice: 0.9020 , Train Accuracy: 0.9761, Validation Loss: 0.0485, Validation IoU: 0.8511, Validation Dice: 0.9194 , Validation Accuracy: 0.9799
# Epoch 776, Train Loss: 0.0560, Train IoU: 0.8198, Train Dice: 0.9008 , Train Accuracy: 0.9760, Validation Loss: 0.0484, Validation IoU: 0.8516, Validation Dice: 0.9197 , Validation Accuracy: 0.9801
# Epoch 777, Train Loss: 0.0536, Train IoU: 0.8271, Train Dice: 0.9052 , Train Accuracy: 0.9770, Validation Loss: 0.0477, Validation IoU: 0.8542, Validation Dice: 0.9212 , Validation Accuracy: 0.9804
# Epoch 778, Train Loss: 0.0579, Train IoU: 0.8151, Train Dice: 0.8979 , Train Accuracy: 0.9753, Validation Loss: 0.0489, Validation IoU: 0.8503, Validation Dice: 0.9190 , Validation Accuracy: 0.9799
# Epoch 779, Train Loss: 0.0572, Train IoU: 0.8174, Train Dice: 0.8993 , Train Accuracy: 0.9755, Validation Loss: 0.0486, Validation IoU: 0.8519, Validation Dice: 0.9199 , Validation Accuracy: 0.9800
# Epoch 780, Train Loss: 0.0569, Train IoU: 0.8186, Train Dice: 0.9001 , Train Accuracy: 0.9756, Validation Loss: 0.0478, Validation IoU: 0.8539, Validation Dice: 0.9211 , Validation Accuracy: 0.9803
# Epoch 781, Train Loss: 0.0543, Train IoU: 0.8261, Train Dice: 0.9046 , Train Accuracy: 0.9768, Validation Loss: 0.0487, Validation IoU: 0.8497, Validation Dice: 0.9186 , Validation Accuracy: 0.9799
# Epoch 782, Train Loss: 0.0553, Train IoU: 0.8236, Train Dice: 0.9031 , Train Accuracy: 0.9765, Validation Loss: 0.0481, Validation IoU: 0.8529, Validation Dice: 0.9205 , Validation Accuracy: 0.9801
# Epoch 783, Train Loss: 0.0529, Train IoU: 0.8302, Train Dice: 0.9070 , Train Accuracy: 0.9773, Validation Loss: 0.0481, Validation IoU: 0.8533, Validation Dice: 0.9207 , Validation Accuracy: 0.9803
# Epoch 784, Train Loss: 0.0561, Train IoU: 0.8188, Train Dice: 0.9002 , Train Accuracy: 0.9759, Validation Loss: 0.0470, Validation IoU: 0.8570, Validation Dice: 0.9228 , Validation Accuracy: 0.9807
# Epoch 785, Train Loss: 0.0539, Train IoU: 0.8270, Train Dice: 0.9052 , Train Accuracy: 0.9769, Validation Loss: 0.0482, Validation IoU: 0.8540, Validation Dice: 0.9211 , Validation Accuracy: 0.9802
# Epoch 786, Train Loss: 0.0551, Train IoU: 0.8234, Train Dice: 0.9030 , Train Accuracy: 0.9764, Validation Loss: 0.0481, Validation IoU: 0.8533, Validation Dice: 0.9207 , Validation Accuracy: 0.9802
# Epoch 787, Train Loss: 0.0549, Train IoU: 0.8233, Train Dice: 0.9027 , Train Accuracy: 0.9764, Validation Loss: 0.0485, Validation IoU: 0.8504, Validation Dice: 0.9190 , Validation Accuracy: 0.9798
# Epoch 788, Train Loss: 0.0558, Train IoU: 0.8205, Train Dice: 0.9011 , Train Accuracy: 0.9761, Validation Loss: 0.0484, Validation IoU: 0.8528, Validation Dice: 0.9204 , Validation Accuracy: 0.9801
# Epoch 789, Train Loss: 0.0571, Train IoU: 0.8156, Train Dice: 0.8984 , Train Accuracy: 0.9754, Validation Loss: 0.0470, Validation IoU: 0.8563, Validation Dice: 0.9224 , Validation Accuracy: 0.9807
# Epoch 790, Train Loss: 0.0519, Train IoU: 0.8320, Train Dice: 0.9082 , Train Accuracy: 0.9778, Validation Loss: 0.0466, Validation IoU: 0.8582, Validation Dice: 0.9236 , Validation Accuracy: 0.9809
# Epoch 791, Train Loss: 0.0551, Train IoU: 0.8218, Train Dice: 0.9019 , Train Accuracy: 0.9763, Validation Loss: 0.0468, Validation IoU: 0.8571, Validation Dice: 0.9229 , Validation Accuracy: 0.9807
# Epoch 792, Train Loss: 0.0527, Train IoU: 0.8314, Train Dice: 0.9078 , Train Accuracy: 0.9775, Validation Loss: 0.0463, Validation IoU: 0.8599, Validation Dice: 0.9245 , Validation Accuracy: 0.9810
# Epoch 793, Train Loss: 0.0526, Train IoU: 0.8310, Train Dice: 0.9075 , Train Accuracy: 0.9775, Validation Loss: 0.0466, Validation IoU: 0.8573, Validation Dice: 0.9230 , Validation Accuracy: 0.9809
# Epoch 794, Train Loss: 0.0509, Train IoU: 0.8366, Train Dice: 0.9109 , Train Accuracy: 0.9782, Validation Loss: 0.0461, Validation IoU: 0.8599, Validation Dice: 0.9245 , Validation Accuracy: 0.9811
# Epoch 795, Train Loss: 0.0568, Train IoU: 0.8176, Train Dice: 0.8994 , Train Accuracy: 0.9755, Validation Loss: 0.0463, Validation IoU: 0.8603, Validation Dice: 0.9247 , Validation Accuracy: 0.9811
# Epoch 796, Train Loss: 0.0560, Train IoU: 0.8206, Train Dice: 0.9012 , Train Accuracy: 0.9761, Validation Loss: 0.0477, Validation IoU: 0.8537, Validation Dice: 0.9209 , Validation Accuracy: 0.9803
# Epoch 797, Train Loss: 0.0535, Train IoU: 0.8282, Train Dice: 0.9059 , Train Accuracy: 0.9771, Validation Loss: 0.0464, Validation IoU: 0.8587, Validation Dice: 0.9238 , Validation Accuracy: 0.9810
# Epoch 798, Train Loss: 0.0517, Train IoU: 0.8338, Train Dice: 0.9092 , Train Accuracy: 0.9780, Validation Loss: 0.0461, Validation IoU: 0.8590, Validation Dice: 0.9240 , Validation Accuracy: 0.9811
# Epoch 799, Train Loss: 0.0559, Train IoU: 0.8202, Train Dice: 0.9010 , Train Accuracy: 0.9760, Validation Loss: 0.0465, Validation IoU: 0.8569, Validation Dice: 0.9228 , Validation Accuracy: 0.9809
# Epoch 800, Train Loss: 0.0561, Train IoU: 0.8195, Train Dice: 0.9007 , Train Accuracy: 0.9758, Validation Loss: 0.0467, Validation IoU: 0.8568, Validation Dice: 0.9227 , Validation Accuracy: 0.9808
